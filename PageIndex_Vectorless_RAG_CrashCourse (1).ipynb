# %% [markdown]
# # 📑 PageIndex — Vectorless RAG Crash Course
# ### Reasoning-based RAG with No Vector DB, No Chunking
# **By [@krishnaik06](https://youtube.com/@krishnaik06) | [krishnaik.in/liveclasses](https://krishnaik.in/liveclasses)**
#
# ---
#
# ## 🧠 What You'll Learn
#
# | # | Topic |
# |---|-------|
# | 1 | Why Vector RAG fails on professional documents |
# | 2 | How PageIndex builds a tree index from a PDF |
# | 3 | LLM Tree Search — reasoning over structure |
# | 4 | Full end-to-end Vectorless RAG pipeline |
# | 5 | Expert-guided retrieval (domain knowledge injection) |
# | 6 | Chat API — zero LLM setup |
# | 7 | Self-hosted open-source option |
#
# ---
#
# ## 🔑 Key Concept
#
# > **Traditional RAG** → chunk → embed → cosine similarity → retrieve
# > **PageIndex RAG** → build tree → LLM reasons over tree → retrieve exact sections
#
# **The problem with vector RAG:**
# `Similarity ≠ Relevance`
# A chunk about "market conditions" may score higher than the actual answer section just because it shares more words with your query.

# %% [markdown]
# ---
# ## 📦 Section 1: Install & Setup
#
# **What we do here:**
# - Install PageIndex SDK + OpenAI
# - Load API keys from `.env`
# - Initialize both clients
#
# > 🔑 Get your **PageIndex API key** from: https://dash.pageindex.ai/api-keys
# > 🔑 Get your **OpenAI API key** from: https://platform.openai.com

# %%
# Install required packages
# !pip install -U pageindex openai python-dotenv
# Out:
# Collecting pageindex
#   Downloading pageindex-0.2.8-py3-none-any.whl.metadata (628 bytes)
# Collecting openai
#   Downloading openai-2.36.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: python-dotenv in d:\python scripts\generative ai\arise\arise\lib\site-packages (1.2.1)
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from pageindex) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from requests<3.0.0,>=2.25.0->pageindex) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from requests<3.0.0,>=2.25.0->pageindex) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from requests<3.0.0,>=2.25.0->pageindex) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from requests<3.0.0,>=2.25.0->pageindex) (2025.11.12)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.14.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in d:\python scripts\generative ai\arise\arise\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: httpcore==1.* in d:\python scripts\generative ai\arise\arise\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\python scripts\generative ai\arise\arise\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in d:\python scripts\generative ai\arise\arise\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading pageindex-0.2.8-py3-none-any.whl (6.0 kB)
# Downloading openai-2.36.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 16.8 MB/s  0:00:00
# Downloading jiter-0.14.0-cp311-cp311-win_amd64.whl (204 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, jiter, openai, pageindex
#
#   Attempting uninstall: python-dotenv
#
#     Found existing installation: python-dotenv 1.2.1
#
#     Uninstalling python-dotenv-1.2.1:
#
#       Successfully uninstalled python-dotenv-1.2.1
#
#    ---------------------------------------- 0/4 [python-dotenv]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    ---------------------------------------- 4/4 [pageindex]
#
# Successfully installed jiter-0.14.0 openai-2.36.0 pageindex-0.2.8 python-dotenv-1.2.2

# %%
# ── Create a .env file (run this once) ──────────────────────────────────────
# Uncomment and fill in your keys, then run this cell ONCE

# env_content = """
# PAGEINDEX_API_KEY=your_pageindex_key_here
# OPENAI_API_KEY=your_openai_key_here
# """
# with open(".env", "w") as f:
#     f.write(env_content.strip())
# print("✅ .env file created")

# %%
import os, json, time
from dotenv import load_dotenv

load_dotenv()

PAGEINDEX_API_KEY = os.getenv("PAGE_INDEX_API_KEY")
OPENAI_API_KEY    = os.getenv("GOOGLE_API_KEY")

print("PageIndex key loaded:", "✅" if PAGEINDEX_API_KEY else "❌ Missing!")
print("OpenAI key loaded:   ", "✅" if OPENAI_API_KEY    else "❌ Missing!")
# Out:
# PageIndex key loaded: ✅
# OpenAI key loaded:    ✅

# %%
from pageindex import PageIndexClient


pi_client     = PageIndexClient(api_key=PAGEINDEX_API_KEY)
# First, ensure you have it installed: pip install langchain-google-genai

from google import genai
import os

from groq import Groq
import os

client = Groq(api_key=os.getenv("GROQ_API_KEY"))

print("✅ PageIndex client ready")
print("✅ ChatGroq client ready")
# Out:
# ✅ PageIndex client ready
# ✅ ChatGroq client ready

# %% [markdown]
# ---
# ## 🌲 Section 2: Upload & Index a PDF
#
# **What happens here:**
# 1. Upload your PDF to the PageIndex cloud
# 2. PageIndex uses an LLM to read the document structure
# 3. Builds a hierarchical **tree index** (like a smart Table of Contents)
# 4. Returns a `doc_id` for all future operations
#
# **Why NO chunking?**
# Instead of cutting the document into arbitrary 500-token pieces, PageIndex respects the document's natural section boundaries — chapters, sub-sections, paragraphs — as the author intended.

# %%
# ── Upload your PDF ─────────────────────────────────────────────────────────
# Replace with the path to your PDF file
# Great candidates: Annual reports, research papers, legal docs, textbooks

PDF_PATH = "D:\\python scripts\\Generative AI\\arise_chatbot\\data\\petitions\\tariff_petition_jusnl.pdf"   # ← change this

print(f"📤 Uploading: {PDF_PATH}")
result = pi_client.submit_document(PDF_PATH)
doc_id = result["doc_id"]

print(f"✅ Uploaded!")
print(f"📋 Document ID: {doc_id}")
print("   (Save this ID — you'll use it throughout the notebook)")
# Out:
# 📤 Uploading: D:\python scripts\Generative AI\arise_chatbot\data\petitions\tariff_petition_jusnl.pdf
# ✅ Uploaded!
# 📋 Document ID: pi-cmp5hk977018401qwda80gy5k
#    (Save this ID — you'll use it throughout the notebook)

# %%
# ── Poll until processing is complete ───────────────────────────────────────
# PageIndex builds the tree asynchronously.
# For a 50-page PDF this typically takes 30–90 seconds.

print("⏳ Building tree index...")
print("   (This runs once per document — the index is cached for reuse)")

while True:
    status_result = pi_client.get_document(doc_id)
    status = status_result.get("status")
    print(f"   Status: {status}")

    if status == "completed":
        print("\n✅ Tree index ready!")
        break
    elif status == "failed":
        print("\n❌ Processing failed. Check your PDF format.")
        break

    time.sleep(5)
# Out:
# ⏳ Building tree index...
#    (This runs once per document — the index is cached for reuse)
#    Status: processing
#    Status: processing
#    Status: processing
#    Status: processing
#    Status: processing
#    Status: completed
#
# ✅ Tree index ready!

# %% [markdown]
# ---
# ## 🔍 Section 3: Inspect the Tree Structure
#
# **What the tree looks like:**
#
# ```
# Document
# ├── Introduction (pages 1-3)
# │   └── Background (pages 1-2)
# ├── Financial Stability (pages 21-31)
# │   ├── Monitoring Vulnerabilities (pages 22-28)
# │   └── International Cooperation (pages 28-31)
# └── Conclusion (pages 45-47)
# ```
#
# Each node has:
# - `node_id` — unique ID used during retrieval
# - `title` — section heading
# - `page_index` — page number in original PDF
# - `text` — section summary (when `node_summary=True`)
# - `nodes` — child sections (nested)
#
# **This structure is what the LLM reasons over during retrieval.**

# %%
# ── Fetch the full tree ─────────────────────────────────────────────────────
tree_result  = pi_client.get_tree(doc_id, node_summary=True)
pageindex_tree = tree_result.get("result", [])

print(f"📊 Top-level sections: {len(pageindex_tree)}")
print("\n🌲 Raw tree (first node):")
print(json.dumps(pageindex_tree[0] if pageindex_tree else {}, indent=2))
# Out:
# 📊 Top-level sections: 9
#
# 🌲 Raw tree (first node):
# {
#   "title": "BEFORE",
#   "node_id": "0000",
#   "page_index": 1,
#   "summary": "# BEFORE\n",
#   "text": "# BEFORE\n"
# }

# %%
# print(pageindex_tree[1].keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(pageindex_tree[1].keys())
#
# NameError: name 'pageindex_tree' is not defined

# %%
# ── Pretty-print the full tree ───────────────────────────────────────────────
def print_tree(nodes, indent=0):
    """Recursively print tree titles for a visual overview."""
    for node in nodes:
        prefix = "  " * indent + ("└─ " if indent > 0 else "")
        page   = node.get("page_index", "?")
        print(f"{prefix}[{node['node_id']}] {node['title']}  (p.{page})")
        if node.get("nodes"):
            print_tree(node["nodes"], indent + 1)

print("📚 Full Document Structure:\n")
print_tree(pageindex_tree)
# Out:
# 📚 Full Document Structure:
#
# [0000] BEFORE  (p.1)
# [0001] THE HON'BLE JHARKHAND STATE ELECTRICITY REGULATORY COMMISSION  (p.1)
#   └─ [0002] BEFORE THE JHARKHAND STATE ELECTRICITY REGULATORY COMMISSION, RANCHI  (p.2)
#   └─ [0003] Prayers before the Hon'ble Commission:  (p.3)
#   └─ [0004] Contents  (p.5)
#   └─ [0005] List of Tables  (p.7)
# [0006] 1. Introduction  (p.8)
#   └─ [0007] 1.1. Background  (p.8)
#   └─ [0008] 1.2. Profile of JUSNL  (p.9)
#   └─ [0009] 1.3. Procedural History  (p.11)
#   └─ [0010] 1.4. Rationale for filing of Instant Petition  (p.12)
#   └─ [0011] 1.5. Contents of the Petition  (p.12)
# [0012] 2. Overall Approach and Provision of Law  (p.13)
# [0013] 3. Provisional True up For FY 2023-24  (p.15)
#   └─ [0014] 3.1. Preamble  (p.15)
#   └─ [0015] 3.2. Basis of True up  (p.15)
#   └─ [0016] 3.3. Capital Expenditure, Capitalization and CWIP  (p.15)
#   └─ [0017] 3.4. Gross Fixed Asset  (p.16)
#   └─ [0018] 3.5. Operation and Maintenance Expenses  (p.17)
#   └─ [0019] 3.6. Depreciation  (p.21)
#   └─ [0020] 3.7. Interest and Loan capital  (p.23)
#   └─ [0021] 3.8. Return on Equity  (p.23)
#   └─ [0022] 3.9. Interest on Working Capital  (p.24)
#   └─ [0023] 3.10. Non-Tariff Income  (p.25)
#   └─ [0024] 3.11. Tax on income  (p.26)
#   └─ [0025] 3.12. Incentive for Target Availability  (p.26)
#   └─ [0026] 3.13. Revenue from Operations  (p.28)
#   └─ [0027] 3.14. Net ARR and revenue gap for FY 2023-24  (p.29)
#   └─ [0028] 3.15. Cumulative Revenue Gap till FY 2023-24  (p.30)
# [0029] 4. APR for the FY 2024-25  (p.32)
#   └─ [0030] 4.1. Preamble  (p.32)
#   └─ [0031] 4.2. Capital Expenditure and Capitalization  (p.32)
#   └─ [0032] 4.3. Gross Fixed Asset  (p.32)
#   └─ [0033] 4.4. Debt Equity Ratio  (p.33)
#   └─ [0034] 4.5. Operation and Maintenance Expenses  (p.34)
#   └─ [0035] 4.6. Depreciation  (p.38)
#   └─ [0036] 4.7. Interest Expenses  (p.40)
#   └─ [0037] 4.8. Return on Equity  (p.42)
#   └─ [0038] 4.9. Interest on Working Capital  (p.43)
#   └─ [0039] 4.10. Non-Tariff Income  (p.44)
#   └─ [0040] 4.11. ARR for the FY 2024-25  (p.45)
# [0041] 5. ARR for the FY 2025-26  (p.46)
#   └─ [0042] 5.1. Preamble  (p.46)
#   └─ [0043] 5.2. Capital Expenditure and Capitalization  (p.46)
#   └─ [0044] 5.3. Gross Fixed Asset  (p.46)
#   └─ [0045] 5.4. Debt Equity Ratio  (p.47)
#   └─ [0046] 5.5. Operation and Maintenance Expenses  (p.48)
#     └─ [0047] Employee Expense  (p.49)
#     └─ [0048] Administrative and General Expenses  (p.51)
#     └─ [0049] Repair and maintenance Expenses  (p.52)
#     └─ [0050] Gist of O&amp;M Expenses  (p.53)
#   └─ [0051] 5.6. Depreciation  (p.53)
#   └─ [0052] 5.7. Interest Expenses  (p.55)
#   └─ [0053] 5.8. Return on Equity  (p.57)
#   └─ [0054] 5.9. Interest on Working Capital  (p.58)
#   └─ [0055] 5.10. Non-Tariff Income  (p.59)
#   └─ [0056] 5.11. ARR for the FY 2025-26  (p.59)
# [0057] 6. Determination of Transmission Tariff for FY 2025-26  (p.61)
# [0058] 7. Status of Board of Directors approval for Business Plan Schemes  (p.65)

# %%
# ── Count total nodes ────────────────────────────────────────────────────────
def count_nodes(nodes):
    total = len(nodes)
    for n in nodes:
        if n.get("nodes"):
            total += count_nodes(n["nodes"])
    return total

total = count_nodes(pageindex_tree)
print(f"🔢 Total nodes in tree: {total}")
print("   Each node = one retrievable section of the document")
# Out:
# 🔢 Total nodes in tree: 59
#    Each node = one retrievable section of the document

# %% [markdown]
# ---
# ## 🧠 Section 4: LLM Tree Search — The Core of PageIndex
#
# **This is where PageIndex fundamentally differs from vector RAG.**
#
# ### Vector RAG retrieval:
# ```
# query → embed → cosine_similarity(query_vec, all_chunk_vecs) → top-k chunks
# ```
# *Problem: finds what's similar, not what's relevant*
#
# ### PageIndex retrieval:
# ```
# query + tree → LLM reasons → "node 0007 and 0008 contain the answer"
# ```
# *Advantage: LLM understands document structure, context, and intent*
#
# **The LLM acts like a human expert scanning a Table of Contents.**

# %%
# ── LLM Tree Search Function ─────────────────────────────────────────────────

def llm_tree_search(query: str, tree: list, model: str = "llama-3.3-70b-versatile") -> dict:
    """
    Core PageIndex retrieval:
    Sends the query + document tree to an LLM.
    LLM reasons over the structure and returns relevant node_ids.

    Returns: dict with 'thinking' (reasoning) and 'node_list' (node IDs)
    """

    # Compress tree to save tokens — only send titles + short summaries
    def compress(nodes):
        out = []
        for n in nodes:
            entry = {
                "node_id": n["node_id"],
                "title":   n["title"],
                "page":    n.get("page_index", "?"),
                "summary": n.get("text", "")[:150]  # first 150 chars
            }
            if n.get("nodes"):
                entry["children"] = compress(n["nodes"])
            out.append(entry)
        return out

    compressed_tree = compress(tree)

    prompt = f"""You are given a query and a document's tree structure (like a Table of Contents).
Your task: identify which node IDs most likely contain the answer to the query.
Think step-by-step about which sections are relevant.

Query: {query}

Document Tree:
{json.dumps(compressed_tree, indent=2)}

Reply ONLY in this exact JSON format:
{{
  "thinking": "<your step-by-step reasoning>",
  "node_list": ["node_id1", "node_id2"]
}}"""

    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        response_format={"type": "json_object"}
    )

    return json.loads(response.choices[0].message.content)

# %%
# ── Test with a sample query ─────────────────────────────────────────────────
query = "actual employee cost FY 2023-24 Rs crore"

print(f"🔍 Query: {query}\n")
result = llm_tree_search(query, pageindex_tree)

print("🧠 LLM Reasoning:")
print(result.get("thinking", "N/A"))
print()
print("🎯 Selected Node IDs:", result.get("node_list", []))
# Out:
# 🔍 Query: actual employee cost FY 2023-24 Rs crore
#
# 🧠 LLM Reasoning:
# To find the node IDs that most likely contain the answer to the query 'actual employee cost FY 2023-24 Rs crore', we first look for sections related to costs or expenses. The query specifically mentions 'employee cost' and 'FY 2023-24', which helps narrow down the search. Section 3 is titled 'Provisional True up For FY 2023-24', making it highly relevant. Within this section, we look for mentions of employee costs or expenses. Node '0018' with title '3.5. Operation and Maintenance Expenses' is particularly relevant because operation and maintenance expenses often include employee costs. Additionally, any sections discussing financial projections or true-ups for the specified fiscal year could potentially include the required information. However, given the specificity of the query, '0018' and its parent node '0013' which deals with the provisional true-up for FY 2023-24 are the most directly relevant.
#
# 🎯 Selected Node IDs: ['0013', '0018', '0047']

# %%
from google import genai
from google.genai import types
import json
import os

# ── Gemini Client ────────────────────────────────────────────────────────────
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))


# ── LLM Tree Search Function ─────────────────────────────────────────────────
def llm_tree_search(
    query: str,
    tree: list,
    model: str = "gemini-2.5-flash-lite"
) -> dict:
    """
    Core PageIndex retrieval:
    Sends the query + document tree to Gemini.
    Gemini reasons over the structure and returns relevant node_ids.

    Returns:
        {
            "thinking": "...",
            "node_list": [...]
        }
    """

    # Compress tree to save tokens
    def compress(nodes):
        out = []

        for n in nodes:
            entry = {
                "node_id": n["node_id"],
                "title": n["title"],
                "page": n.get("page_index", "?"),
                "summary": n.get("text", "")[:150]
            }

            if n.get("nodes"):
                entry["children"] = compress(n["nodes"])

            out.append(entry)

        return out

    compressed_tree = compress(tree)

    prompt = f"""
You are given a query and a document's tree structure
(like a Table of Contents).

Your task:
Identify which node IDs most likely contain the answer.

Think step-by-step before deciding.

Query:
{query}

Document Tree:
{json.dumps(compressed_tree, indent=2)}

Reply ONLY in this exact JSON format:

{{
  "thinking": "<your step-by-step reasoning>",
  "node_list": ["node_id1", "node_id2"]
}}
"""

    response = client.models.generate_content(
        model=model,
        contents=prompt,
        config=types.GenerateContentConfig(
            temperature=0.2,
            response_mime_type="application/json",
            response_schema={
                "type": "OBJECT",
                "properties": {
                    "thinking": {
                        "type": "STRING"
                    },
                    "node_list": {
                        "type": "ARRAY",
                        "items": {
                            "type": "STRING"
                        }
                    }
                },
                "required": ["thinking", "node_list"]
            }
        )
    )

    return response.parsed

query = "actual employee cost FY 2023-24 Rs crore"

result = llm_tree_search(query, pageindex_tree)

print(result["thinking"])
print(result["node_list"])
# Out:
# The user is asking for the "actual employee cost" for the fiscal year 2023-24. I need to find nodes that discuss costs or expenses for FY 2023-24, specifically employee costs.
#
# 1. I will look for sections related to "Provisional True up For FY 2023-24" (node 0013).
# 2. Within that section, I will search for "Operation and Maintenance Expenses" (node 0018) as employee costs are typically part of O&M.
# 3. Node 0018's summary mentions "Employee Expenses" as part of Operation and Maintenance (O&M) costs. This is a strong candidate.
# 4. I will also check other sections that might contain cost information for FY 2023-24, but node 0018 seems most direct for employee costs. Node 0014 mentions "actual performance of the JUSNL during the FY 2023-24", which is relevant but node 0018 specifically mentions employee expenses.
# 5. Node 0046 discusses O&M expenses for FY 2024-25, which is not the correct year. Node 0034 also discusses O&M for FY 2024-25.
# 6. Therefore, node 0018 is the most relevant node for "actual employee cost FY 2023-24".
# ['0018']

# %% [markdown]
# ---
# ## ⚙️ Section 5: Full End-to-End RAG Pipeline
#
# **3 steps:**
# 1. **Tree Search** → LLM picks relevant `node_ids`
# 2. **Retrieve** → Fetch the actual section content from those nodes
# 3. **Generate** → LLM writes a grounded answer with page citations
#
# **What makes this better than vector RAG:**
# - Retrieved content has titles + page numbers (traceable)
# - LLM can cite exactly *which section* the answer comes from
# - No hallucination from irrelevant chunks

# %%
# ── Helper: Find nodes by ID ─────────────────────────────────────────────────

def find_nodes_by_ids(tree: list, target_ids: list) -> list:
    """Recursively walk the tree and collect nodes matching target_ids."""
    found = []
    for node in tree:
        if node["node_id"] in target_ids:
            found.append(node)
        if node.get("nodes"):
            found.extend(find_nodes_by_ids(node["nodes"], target_ids))
    return found

# %%
# ── Generate answer from retrieved nodes ─────────────────────────────────────

def generate_answer(query: str, nodes: list, model: str = "llama-3.3-70b-versatile") -> str:
    """
    Takes retrieved nodes as context and generates a grounded answer.
    Instructs the LLM to cite section titles and page numbers.
    """
    if not nodes:
        return "⚠️ No relevant sections found in the document."

    # Build context string from retrieved nodes
    context_parts = []
    for node in nodes:
        context_parts.append(
            f"[Section: '{node['title']}' | Page {node.get('page_index', '?')}]\n"
            f"{node.get('text', 'Content not available.')}"
        )
    context = "\n\n---\n\n".join(context_parts)

    prompt = f"""You are an expert document analyst.
Answer the question using ONLY the provided context.
For every claim you make, cite the section title and page number in parentheses.
Be concise and precise.

Question: {query}

Context:
{context}

Answer:"""

    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}]
    )

    return response.choices[0].message.content

# %%
# ── The complete Vectorless RAG function ─────────────────────────────────────

def vectorless_rag(query: str, tree: list, verbose: bool = True) -> str:
    """
    Full end-to-end PageIndex RAG pipeline:

    Step 1: LLM Tree Search  → finds relevant node_ids
    Step 2: Node Retrieval   → fetches section content
    Step 3: Answer Generation → produces cited answer
    """
    if verbose:
        print(f"{'='*55}")
        print(f"🔍 Query: {query}")
        print(f"{'='*55}")

    # Step 1: Tree Search
    search_result  = llm_tree_search(query, tree)
    node_ids       = search_result.get("node_list", [])

    if verbose:
        print(f"\n🧠 Reasoning: {search_result.get('thinking', '')[:200]}...")
        print(f"🎯 Retrieved node IDs: {node_ids}")

    # Step 2: Retrieve nodes
    nodes = find_nodes_by_ids(tree, node_ids)

    if verbose:
        print(f"📄 Sections found: {[n['title'] for n in nodes]}")

    # Step 3: Generate answer
    answer = generate_answer(query, nodes)

    if verbose:
        print(f"\n📝 Answer:\n{answer}")

    return answer

# %%
# ── Run the full pipeline ────────────────────────────────────────────────────
answer = vectorless_rag(
    query="actual employee cost FY 2023-24 Rs crore",
    tree=pageindex_tree
)
# Out:
# =======================================================
# 🔍 Query: actual employee cost FY 2023-24 Rs crore
# =======================================================
#
# 🧠 Reasoning: To find the node IDs most likely to contain the answer to the query 'actual employee cost FY 2023-24 Rs crore', we need to analyze the document tree structure and identify sections related to employee...
# 🎯 Retrieved node IDs: ['0013', '0018', '0047']
# 📄 Sections found: ['3. Provisional True up For FY 2023-24', '3.5. Operation and Maintenance Expenses', 'Employee Expense']
#
# 📝 Answer:
# The actual employee cost for FY 2023-24 is Rs. 90.31 crore (Section: '3.5. Operation and Maintenance Expenses' | Page 17-18).

# %%
# ── Test with multiple queries ───────────────────────────────────────────────
test_queries = [
    "What is the ARR claimed by JUSNL for FY 2025-26?",
    "What is the approved ARR for FY 2025-26 for JUSNL?",
    "Compare approved vs actual capitalization across FY24, FY25 and FY26",
]

for q in test_queries:
    print()
    ans = vectorless_rag(q, pageindex_tree, verbose=False)
    print(f"Q: {q}")
    print(f"A: {ans[:]}...")
    print("-" * 55)
# Out:
# Q: What is the ARR claimed by JUSNL for FY 2025-26?
# A: The ARR claimed by JUSNL for FY 2025-26 is 1,418.88 (5.11. ARR for the FY 2025-26, Page 59)....
# -------------------------------------------------------
#
# Q: What is the approved ARR for FY 2025-26 for JUSNL?
# A: The approved ARR for FY 2025-26 for JUSNL is 475.40 (5.11. ARR for the FY 2025-26, Page 59)....
# -------------------------------------------------------
#
# Q: Compare approved vs actual capitalization across FY24, FY25 and FY26
# A: Comparison of approved vs actual capitalization across FY24, FY25, and FY26 is as follows:
#
# - FY24: Actual capitalization is Rs. 7.51 Crore (3.3.7, Page 15), while approved capitalization in T.O. dated 23.06.2023 is Rs. 29.99 Crore and in T.O. dated 03.07.2024 is Rs. 215.07 Crore (Table 4, 3.3.6, Page 15).
# - FY25: Approved capitalization is Rs. 528.95 Crore (Table 22, 4.2.2, Page 32). No actual figures are provided.
# - FY26: Approved capitalization is Rs. 2,793.43 Crore (Table 37, 5.2.2, Page 46). No actual figures are provided....
# -------------------------------------------------------

# %% [markdown]
# ---
# ## 🎓 Section 6: Expert-Guided Retrieval
#
# **The killer feature no one talks about.**
#
# With vector RAG, injecting domain expertise requires **fine-tuning the embedding model** — expensive and time-consuming.
#
# With PageIndex, you just **add rules to the prompt**:
#
# ```
# "If the query mentions EBITDA → prioritize the MD&A section"
# "If the query is about risks  → check Part I, Item 1A"
# ```
#
# This makes PageIndex instantly adaptable to any domain — finance, legal, medical, technical — without any model training.

# %%
# ── Define domain expert rules ───────────────────────────────────────────────
# These are routing rules that tell the LLM WHERE to look for specific queries.
# Think of it as encoding a senior analyst's institutional knowledge.

# %%
FINANCIAL_EXPERT_RULES = """
Expert routing rules for financial documents (10-K, annual reports):
- EBITDA, profitability queries    → MD&A section (Management Discussion & Analysis)
- Liquidity, cash flow queries     → Cash Flow Statement + liquidity footnotes
- Risk factor queries              → Part I, Item 1A (Risk Factors)
- Revenue breakdown queries        → Segment reporting or Item 7
- Forward-looking / strategy       → CEO letter, Outlook, Strategy section
- Debt, credit, leverage queries   → Balance Sheet + debt footnotes
- Regulatory / compliance queries  → Legal Proceedings or regulatory filings
"""

print("✅ Expert rules defined")
print("   These get injected into the retrieval prompt at query time.")

# %%
# ── Expert Routing Rules — Advanced Route of Learning AI ─────────────────────
# Krish Naik Academy | 21 Modules | 38 Sections | 481 Topics
FINANCIAL_EXPERT_RULES = """
Route queries to the correct module using these rules:

M1  Neural Network Refresher   → backprop, activations, optimizers, PyTorch basics
M2  Hardware                   → GPU, TPU, Apple Silicon, compute infrastructure
M3  Transformers 101           → attention, self-attention, encoder-decoder, MHA
M4  Tokenization               → BPE, WordPiece, SentencePiece, Byte Latent Transformers
M5  Finetuning Architectures   → hands-on BERT/GPT/T5 finetuning, Hugging Face
M6  KV Cache & Attention       → KV cache, Flash Attention, MQA, GQA, RoPE, vLLM
M7  Scaling Laws               → Kaplan, Chinchilla, compute-optimal training
M8  Mixture of Experts         → MoE, sparse computation, Mixture of Depths
M9  Modern LLM Finetuning      → LoRA, QLoRA, SFT, DPO, PPO, RLHF, GRPO, ORPO,
                                  quantization, TRL, Unsloth, synthetic data,
                                  reasoning models, evaluation, deployment
M10 SLM                        → small language models, pruning, when SLM vs LLM
M11 Knowledge Distillation     → student-teacher, soft labels, DistilBERT, DeepSeek-R1
M12 Hybrid Architectures       → Mamba, RWKV, SSMs, Jamba, Nemotron, beyond Transformers
M13 Vision Foundations         → ViT, patch embeddings, CLIP, SigLIP, DINOv2
M14 Visual Language Models     → VLM architecture, aligner, multimodal reasoning
M15 Stable Diffusion & DiT     → DDPM, latent diffusion, FLUX.1, ControlNet, DreamBooth
M16 Embedding Models           → dense, sparse, binary, Matryoshka, MRL, fine-tuning
M17 RAG                        → chunking, BM25, ColBERT, hybrid RAG, rerankers,
                                  self/corrective/adaptive/agentic RAG, Graph RAG,
                                  multi-modal RAG, ColPali, RAG security
M18 Context Engineering        → prompt vs context engineering, memory architecture,
                                  context compression, KV cache, agent context lifecycle
M19 DSPy                       → signatures, modules, MIPROv2, self-optimizing RAG
M20 Agents                     → ReAct, MCP, LangGraph, CrewAI, browser agents,
                                  A2A, guardrails, observability, evaluation
M21 RL                         → PPO, GRPO, DAPO, GSPO, CISPO, reward models,
                                  RLHF vs RLVR, policy gradient, DeepSeek-R1 training

Cross-cutting rules:
- "learning path / where to start"     → M1 → M2 → M3 in order
- "production / deployment / serving"  → M9 (quantization) + M20 (agents)
- "fine-tuning vs RAG"                 → M9 + M17 + M18
- "multimodal / vision + language"     → M13 + M14 + M17 (multi-modal RAG)
- "reasoning models / test-time RL"    → M9 (reasoning) + M21 (GRPO/DAPO)
"""

# %%
# ── Expert-guided tree search ────────────────────────────────────────────────

def llm_tree_search_with_expert(
    query: str,
    tree: list,
    expert_rules: str,
    model: str = "gpt-4o"
) -> dict:
    """
    Same as llm_tree_search() but with domain expert rules injected.
    The LLM uses these rules to guide its reasoning.
    """

    def compress(nodes):
        out = []
        for n in nodes:
            entry = {"node_id": n["node_id"], "title": n["title"],
                     "page": n.get("page_index", "?"),
                     "summary": n.get("text", "")[:150]}
            if n.get("nodes"):
                entry["children"] = compress(n["nodes"])
            out.append(entry)
        return out

    prompt = f"""You are a domain expert analyzing a document.
Find all node IDs that most likely contain the answer to the query.
Use the expert routing rules below to guide your reasoning.

Query: {query}

Document Tree:
{json.dumps(compress(tree), indent=2)}

Expert Routing Rules (follow these carefully):
{expert_rules}

Reply ONLY in this JSON format:
{{
  "thinking": "<your reasoning, referencing the expert rules>",
  "node_list": ["node_id1", "node_id2"]
}}"""

    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        response_format={"type": "json_object"}
    )
    return json.loads(response.choices[0].message.content)

# %%
# ── Test expert-guided retrieval ─────────────────────────────────────────────
query = "Details of the modern llm finetuning?"

print(f"🔍 Query: {query}\n")

# Without expert rules
print("── Without Expert Rules ──")
basic   = llm_tree_search(query, pageindex_tree)
print("Nodes:", basic.get("node_list"))

print()

# With expert rules
print("── With Expert Rules ──")
guided  = llm_tree_search_with_expert(query, pageindex_tree, FINANCIAL_EXPERT_RULES)
print("Nodes:", guided.get("node_list"))
print("Reasoning:", guided.get("thinking", "")[:300])
# Out:
# 🔍 Query: Details of the modern llm finetuning?
#
# ── Without Expert Rules ──
# Nodes: ['0010', '0011', '0012', '0013', '0014', '0015', '0016', '0017', '0018', '0019', '0020', '0021']
#
# ── With Expert Rules ──
# Nodes: ['0010', '0014', '0015', '0016', '0018', '0020']
# Reasoning: Based on the expert routing rules, the query 'Details of the modern llm finetuning?' aligns with M9, which covers Modern LLM Finetuning. This module includes topics like LoRA, QLoRA, SFT, DPO, PPO, RLHF, GRPO, ORPO, quantization, evaluation, and deployment, all of which are part of modern LLM fine-t

# %%
# ── Full expert-guided RAG ───────────────────────────────────────────────────

def expert_rag(query: str, tree: list, rules: str) -> str:
    """Expert-guided end-to-end RAG pipeline."""
    result  = llm_tree_search_with_expert(query, tree, rules)
    nodes   = find_nodes_by_ids(tree, result.get("node_list", []))
    return generate_answer(query, nodes)

# Run it
answer = expert_rag(
    query="Details of the syllabus of modern llm finetuning",
    tree=pageindex_tree,
    rules=FINANCIAL_EXPERT_RULES
)
print(answer)
# Out:
# The syllabus for modern LLM fine-tuning includes several key components and techniques:
#
# 1. **Comprehensive Fine-Tuning Stack**: Pre-training, data preparation, parameter-efficient fine-tuning (PEFT), supervised fine-tuning (SFT), preference alignment, evaluation, quantization, tooling, and synthetic data generation are part of the modern LLM fine-tuning stack (Section: 'Modern LLMs Finetuning' | Page 12).
#
# 2. **Pre-Training**: Focuses on data curation, continued pre-training for domain adaptation, and architectural strategies like shared trunk with separate heads (Section: 'Pre-Training Deep Dive' | Page 12).
#
# 3. **Data Preparation**: Involves handling dataset formats, chat templates, and addressing loss masking and deduplication issues (Section: 'Data Preparation for Fine-Tuning' | Page 12).
#
# 4. **Parameter-Efficient Fine-Tuning (PEFT)**: Includes techniques such as LoRA, QLoRA, and adapter tuning, focusing on efficient model adjustment without full retraining (Section: 'Parameter-Efficient Fine-Tuning (PEFT)' | Page 13).
#
# 5. **Supervised Fine-Tuning (SFT)**: Consists of instruction tuning, conversational fine-tuning, and domain-specific practices (Section: 'Supervised Fine-Tuning (SFT)' | Page 13).
#
# 6. **Preference Alignment**: Utilizes techniques such as RLHF with PPO and direct preference optimization methods (Section: 'Preference Alignment' | Page 13).
#
# 7. **Post-Training Pipeline**: Describes the sequence of continued pre-training, SFT, alignment, and reinforcement learning (Section: 'The Modern Post-Training Stack' | Page 14).
#
# 8. **Evaluation**: Involves benchmarks for knowledge, reasoning, and instruction-following, as well as methods to detect overfitting (Section: 'Evaluation' | Page 14).
#
# 9. **Quantization & Deployment Prep**: Covers techniques like GPTQ for efficient model deployment, and using multiple inference frameworks (Section: 'Quantization & Deployment Prep' | Page 14).
#
# 10. **Tooling & Frameworks**: Consists of resources like HuggingFace TRL and Axolotl for configurability and LLaMA-Factory for a no-code interface (Section: 'Tooling & Frameworks' | Page 14).

# %% [markdown]
# ---
# ## 💬 Section 7: Chat API — Zero LLM Setup
#
# **When to use this:**
# - You don't want to manage OpenAI API calls yourself
# - You want a quick Q&A interface over your document
# - You're building a chat product and want PageIndex to handle everything
#
# PageIndex provides its own LLM — you just pass a question and `doc_id`.

# %%
# ── Single question with Chat API ────────────────────────────────────────────
# No OpenAI key needed — PageIndex runs the LLM internally

question = "What are the key findings in this document?"

response = pi_client.chat_completions(
    messages=[{"role": "user", "content": question}],
    doc_id=doc_id
)

answer = response["choices"][0]["message"]["content"]
print("💬 Chat API Answer:")
print(answer)
# Out:
# 💬 Chat API Answer:
# I'll analyze the document structure and extract the key findings from this AI course syllabus.## Key Findings
#
# This is a **comprehensive AI course syllabus** from Krish Naik Academy (2025-2026 cohort) titled "Advanced Route of Learning AI."
#
# ### Scope & Scale
# - **21 modules**, 38 sections, **481 topics**
# - Progression from fundamentals to advanced production-ready AI systems
# - Delivery: Live bootcamp + recorded sessions
#
# ### Core Coverage Areas
#
# **1. Foundations**
# - Neural Networks, Transformers (attention mechanisms, encoder-decoder architectures)
# - Tokenization (BPE, WordPiece, Byte Latent Transformers)
# - Hardware (GPUs, TPUs, Apple Silicon)
#
# **2. Advanced Architectures**
# - Scaling Laws (Kaplan, Chinchilla)
# - Mixture of Experts (MoE) and Mixture of Depths (MoD)
# - Hybrid architectures beyond Transformers: SSMs, Mamba, RWKV
# - KV Cache, Flash Attention, attention variants (MHA, MQA, GQA)
#
# **3. LLM Training & Fine-Tuning (Most Comprehensive Module)**
# - Complete post-training pipeline: Pre-training → SFT → Alignment → RL
# - PEFT techniques: LoRA, QLoRA, DoRA, AdaLoRA, GaLore, VeRA
# - Preference alignment: RLHF, DPO, ORPO, SimPO, KTO, CPO
# - Synthetic data generation, quantization, deployment
#
# **4. Specialized Models**
# - Reasoning Models (DeepSeek-R1-Zero, test-time compute scaling)
# - Small Language Models (SLMs) and Knowledge Distillation
# - Visual Language Models and Vision Foundations (ViT, CLIP, DINO)
# - Diffusion Transformers (Stable Diffusion, DiT, FLUX.1)
#
# **5. Production Systems**
# - RAG (hybrid/agentic RAG, multi-modal, Graph RAG, security)
# - Embeddings (Matryoshka, multi-vector, quantized)
# - Context Engineering vs Prompt Engineering
# - DSPy for programmatic LLM optimization
# - Agents (ReAct, MCP, LangGraph, CrewAI)
# - Reinforcement Learning (PPO, GRPO, RLOO, reward design)
#
# ### Key Frameworks
# PyTorch, Hugging Face TRL, Unsloth, Axolotl, LLaMA-Factory, vLLM, SGLang, LangGraph, CrewAI, DSPy, distilabel
#
# This represents a **complete modern AI curriculum** covering the entire stack from neural network theory to production agent deployment.

# %%
# ── Multi-turn conversation ───────────────────────────────────────────────────
# Keep the full message history for context across turns

conversation_history = []

def chat_with_doc(user_message: str, doc_id: str) -> str:
    """Chat with a document, maintaining conversation history."""
    global conversation_history

    conversation_history.append({"role": "user", "content": user_message})

    response = pi_client.chat_completions(
        messages=conversation_history,
        doc_id=doc_id
    )

    assistant_reply = response["choices"][0]["message"]["content"]
    conversation_history.append({"role": "assistant", "content": assistant_reply})

    return assistant_reply


# Simulate a 3-turn conversation
questions = [
    "What were the main revenue sources last year?",
    "How does that compare to the year before?",
    "What factors drove that change?"
]

for q in questions:
    print(f"\n👤 User: {q}")
    reply = chat_with_doc(q, doc_id)
    print(f"🤖 Assistant: {reply[:400]}...")
    print("-" * 55)

# %% [markdown]
# ---
# ## 🛠️ Section 8: Self-Hosted Open Source Option
#
# **Use this when:**
# - You don't want to send documents to any cloud
# - You need full data privacy / on-prem deployment
# - You want to inspect or customize the tree-building logic
#
# The open-source repo at https://github.com/VectifyAI/PageIndex lets you run the entire pipeline locally using your own OpenAI key.
#
# **What the CLI does:**
# 1. Reads your PDF
# 2. Detects existing Table of Contents (if any)
# 3. Uses GPT-4o to build the hierarchical tree
# 4. Saves a `document_name_pageindex.json` alongside your PDF

# %%
# ── Clone the open-source repo ───────────────────────────────────────────────
# !git clone https://github.com/VectifyAI/PageIndex.git
# %cd PageIndex
# !pip install -r requirements.txt

# %%
# ── Create .env for self-hosted mode ─────────────────────────────────────────
# The local runner uses CHATGPT_API_KEY (not OPENAI_API_KEY)

import os
openai_key = os.getenv("OPENAI_API_KEY", "your_key_here")

with open(".env", "w") as f:
    f.write(f"CHATGPT_API_KEY={openai_key}\n")

print("✅ .env created for self-hosted mode")

# %%
# ── Run PageIndex locally on a PDF ───────────────────────────────────────────
# Optional parameters you can customize:
#   --model                  OpenAI model (default: gpt-4o-2024-11-20)
#   --toc-check-pages        Pages to scan for existing TOC (default: 20)
#   --max-pages-per-node     Max pages per tree node (default: 10)
#   --if-add-node-summary    Include summaries in output (yes/no)

PDF_PATH = "/path/to/your/document.pdf"   # ← change this

# !python run_pageindex.py \
    --pdf_path {PDF_PATH} \
    --model gpt-4o-2024-11-20 \
    --toc-check-pages 20 \
    --max-pages-per-node 10 \
    --if-add-node-summary yes

# %%
# ── Load locally generated tree ──────────────────────────────────────────────
# Output is saved as: <your_pdf_name>_pageindex.json

import json

TREE_JSON_PATH = "/path/to/your/document_pageindex.json"  # ← change this

with open(TREE_JSON_PATH, "r") as f:
    local_tree = json.load(f)

print(f"🌲 Local tree loaded: {count_nodes(local_tree)} total nodes")
print_tree(local_tree)

# %%
# ── Run the same RAG pipeline on the local tree ──────────────────────────────
# Everything from Sections 4–6 works identically with local trees

query  = "Summarize the executive summary section."
answer = vectorless_rag(query, local_tree)

# %% [markdown]
# ---
# ## 📊 Section 9: Vector RAG vs PageIndex — Side-by-Side
#
# ### Architecture Comparison
#
# | Aspect | Traditional Vector RAG | PageIndex (Vectorless RAG) |
# |--------|------------------------|---------------------------|
# | **Document prep** | Chunk into fixed pieces | Build hierarchical tree |
# | **Indexing** | Embed each chunk | LLM reads structure |
# | **Storage** | Vector database | JSON file |
# | **Query processing** | Embed query → ANN search | LLM reasons over tree |
# | **What's retrieved** | Flat anonymous chunks | Named sections + page refs |
# | **Explainability** | ❌ Opaque similarity score | ✅ Traceable reasoning |
# | **Domain expertise** | ❌ Needs embedding fine-tune | ✅ Add rules to prompt |
# | **Infrastructure** | Pinecone / FAISS / ChromaDB | No vector DB needed |
# | **Best for** | Short, diverse documents | Long, structured documents |
# | **FinanceBench accuracy** | ~80% | **98.7%** |
#
# ### When to use which
#
# **Use Vector RAG when:**
# - Documents are short and varied (FAQs, product descriptions)
# - Semantic paraphrase matching is important
# - You need sub-second retrieval on millions of documents
#
# **Use PageIndex when:**
# - Documents are long and professionally structured (reports, manuals, legal docs)
# - You need traceable, cited answers
# - Domain expertise should guide retrieval
# - You want to avoid vector DB infrastructure

# %%
# ── Quick comparison demo ────────────────────────────────────────────────────
# Show how the same query retrieves differently

print("=" * 55)
print("VECTOR RAG approach (conceptual):")
print("=" * 55)
print("""
query_vec = embed_model.encode("What are EBITDA risks?")
chunks    = vector_db.similarity_search(query_vec, k=5)

# Returns: 5 text fragments ranked by cosine distance
# Problem: may return "market risk" chunks, not EBITDA section
# No page numbers, no section context
""")

print("=" * 55)
print("PAGEINDEX approach (actual):")
print("=" * 55)
print("""
result = llm_tree_search("What are EBITDA risks?", tree)

# Returns: node IDs like ["0007", "0012"]
# LLM reasoning: "EBITDA is discussed in MD&A section (node 0007)
#                 and footnotes in Financial Statements (node 0012)"
# Full traceability — section title + page number
""")

# %% [markdown]
# ---
# ## 🧹 Section 10: Cleanup
#
# Delete documents from the PageIndex cloud when you're done
# to keep your storage clean.

# %%
# ── Delete document from cloud ───────────────────────────────────────────────
# WARNING: This permanently deletes the tree index.
# Comment this out if you want to reuse the doc_id later.

# pi_client.delete_document(doc_id)
# print(f"🗑️ Deleted document: {doc_id}")
print("ℹ️ Deletion commented out — uncomment when you're done with this doc_id")

# %% [markdown]
# ---
# ## ✅ Summary
#
# You've now built a complete **Vectorless RAG** system with PageIndex.
#
# ### What you built:
#
# 1. **`llm_tree_search()`** — LLM reasons over document tree to find relevant nodes
# 2. **`find_nodes_by_ids()`** — Retrieve actual section content from tree
# 3. **`generate_answer()`** — LLM produces cited, grounded answers
# 4. **`vectorless_rag()`** — Full pipeline combining all 3 steps
# 5. **`expert_rag()`** — Domain-guided retrieval without any fine-tuning
# 6. **Chat API** — Zero-setup document Q&A
#
# ### Key takeaways:
#
# - `Similarity ≠ Relevance` — the fundamental flaw of vector search
# - Tree-based reasoning gives you **traceable**, **accurate**, **explainable** retrieval
# - Domain expertise injection is just **prompt engineering** — no model training needed
# - 98.7% on FinanceBench vs ~80% for vector RAG
#
# ---
#
# ### 🔗 Resources
# - GitHub: https://github.com/VectifyAI/PageIndex
# - Docs: https://docs.pageindex.ai
# - Chat Platform: https://chat.pageindex.ai
# - Blog: https://pageindex.ai/blog/pageindex-intro
#
# ---
# *Crash course by [@krishnaik06](https://youtube.com/@krishnaik06) | [krishnaik.in/liveclasses](https://krishnaik.in/liveclasses)*

# %%
import requests

url = "https://openrouter.ai/api/v1/models"

response = requests.get(url)

models = response.json()

for model in models["data"][:]:
    print(model["id"])
# Out:
# anthropic/claude-opus-4.7-fast
# perceptron/perceptron-mk1
# inclusionai/ring-2.6-1t:free
# google/gemini-3.1-flash-lite
# baidu/cobuddy:free
# openai/gpt-chat-latest
# x-ai/grok-4.3
# ibm-granite/granite-4.1-8b
# mistralai/mistral-medium-3-5
# openrouter/owl-alpha
# nvidia/nemotron-3-nano-omni-30b-a3b-reasoning:free
# poolside/laguna-xs.2:free
# poolside/laguna-m.1:free
# ~anthropic/claude-haiku-latest
# ~openai/gpt-mini-latest
# ~google/gemini-pro-latest
# ~moonshotai/kimi-latest
# ~google/gemini-flash-latest
# ~anthropic/claude-sonnet-latest
# ~openai/gpt-latest
# qwen/qwen3.5-plus-20260420
# qwen/qwen3.6-flash
# qwen/qwen3.6-35b-a3b
# qwen/qwen3.6-max-preview
# qwen/qwen3.6-27b
# openai/gpt-5.5-pro
# openai/gpt-5.5
# deepseek/deepseek-v4-pro
# deepseek/deepseek-v4-flash:free
# deepseek/deepseek-v4-flash
# inclusionai/ling-2.6-1t
# tencent/hy3-preview
# xiaomi/mimo-v2.5-pro
# xiaomi/mimo-v2.5
# openai/gpt-5.4-image-2
# inclusionai/ling-2.6-flash
# ~anthropic/claude-opus-latest
# openrouter/pareto-code
# baidu/qianfan-ocr-fast
# moonshotai/kimi-k2.6
# anthropic/claude-opus-4.7
# anthropic/claude-opus-4.6-fast
# z-ai/glm-5.1
# google/gemma-4-26b-a4b-it:free
# google/gemma-4-26b-a4b-it
# google/gemma-4-31b-it:free
# google/gemma-4-31b-it
# qwen/qwen3.6-plus
# z-ai/glm-5v-turbo
# arcee-ai/trinity-large-thinking:free
# arcee-ai/trinity-large-thinking
# x-ai/grok-4.20-multi-agent
# x-ai/grok-4.20
# google/lyria-3-pro-preview
# google/lyria-3-clip-preview
# kwaipilot/kat-coder-pro-v2
# rekaai/reka-edge
# xiaomi/mimo-v2-omni
# xiaomi/mimo-v2-pro
# minimax/minimax-m2.7
# openai/gpt-5.4-nano
# openai/gpt-5.4-mini
# mistralai/mistral-small-2603
# z-ai/glm-5-turbo
# nvidia/nemotron-3-super-120b-a12b:free
# nvidia/nemotron-3-super-120b-a12b
# bytedance-seed/seed-2.0-lite
# qwen/qwen3.5-9b
# openai/gpt-5.4-pro
# openai/gpt-5.4
# inception/mercury-2
# openai/gpt-5.3-chat
# google/gemini-3.1-flash-lite-preview
# bytedance-seed/seed-2.0-mini
# google/gemini-3.1-flash-image-preview
# qwen/qwen3.5-35b-a3b
# qwen/qwen3.5-27b
# qwen/qwen3.5-122b-a10b
# qwen/qwen3.5-flash-02-23
# liquid/lfm-2-24b-a2b
# google/gemini-3.1-pro-preview-customtools
# openai/gpt-5.3-codex
# aion-labs/aion-2.0
# google/gemini-3.1-pro-preview
# anthropic/claude-sonnet-4.6
# qwen/qwen3.5-plus-02-15
# qwen/qwen3.5-397b-a17b
# minimax/minimax-m2.5:free
# minimax/minimax-m2.5
# z-ai/glm-5
# qwen/qwen3-max-thinking
# anthropic/claude-opus-4.6
# qwen/qwen3-coder-next
# openrouter/free
# stepfun/step-3.5-flash
# arcee-ai/trinity-large-preview
# moonshotai/kimi-k2.5
# upstage/solar-pro-3
# minimax/minimax-m2-her
# writer/palmyra-x5
# liquid/lfm-2.5-1.2b-thinking:free
# liquid/lfm-2.5-1.2b-instruct:free
# openai/gpt-audio
# openai/gpt-audio-mini
# z-ai/glm-4.7-flash
# openai/gpt-5.2-codex
# bytedance-seed/seed-1.6-flash
# bytedance-seed/seed-1.6
# minimax/minimax-m2.1
# z-ai/glm-4.7
# google/gemini-3-flash-preview
# xiaomi/mimo-v2-flash
# nvidia/nemotron-3-nano-30b-a3b:free
# nvidia/nemotron-3-nano-30b-a3b
# openai/gpt-5.2-chat
# openai/gpt-5.2-pro
# openai/gpt-5.2
# mistralai/devstral-2512
# relace/relace-search
# z-ai/glm-4.6v
# nex-agi/deepseek-v3.1-nex-n1
# essentialai/rnj-1-instruct
# openrouter/bodybuilder
# openai/gpt-5.1-codex-max
# amazon/nova-2-lite-v1
# mistralai/ministral-14b-2512
# mistralai/ministral-8b-2512
# mistralai/ministral-3b-2512
# mistralai/mistral-large-2512
# arcee-ai/trinity-mini
# deepseek/deepseek-v3.2-speciale
# deepseek/deepseek-v3.2
# prime-intellect/intellect-3
# anthropic/claude-opus-4.5
# allenai/olmo-3-32b-think
# google/gemini-3-pro-image-preview
# x-ai/grok-4.1-fast
# deepcogito/cogito-v2.1-671b
# openai/gpt-5.1
# openai/gpt-5.1-chat
# openai/gpt-5.1-codex
# openai/gpt-5.1-codex-mini
# moonshotai/kimi-k2-thinking
# amazon/nova-premier-v1
# perplexity/sonar-pro-search
# mistralai/voxtral-small-24b-2507
# openai/gpt-oss-safeguard-20b
# nvidia/nemotron-nano-12b-v2-vl:free
# minimax/minimax-m2
# qwen/qwen3-vl-32b-instruct
# ibm-granite/granite-4.0-h-micro
# microsoft/phi-4-mini-instruct
# openai/gpt-5-image-mini
# anthropic/claude-haiku-4.5
# qwen/qwen3-vl-8b-thinking
# qwen/qwen3-vl-8b-instruct
# openai/gpt-5-image
# openai/o3-deep-research
# openai/o4-mini-deep-research
# nvidia/llama-3.3-nemotron-super-49b-v1.5
# baidu/ernie-4.5-21b-a3b-thinking
# google/gemini-2.5-flash-image
# qwen/qwen3-vl-30b-a3b-thinking
# qwen/qwen3-vl-30b-a3b-instruct
# openai/gpt-5-pro
# z-ai/glm-4.6
# anthropic/claude-sonnet-4.5
# deepseek/deepseek-v3.2-exp
# thedrummer/cydonia-24b-v4.1
# relace/relace-apply-3
# google/gemini-2.5-flash-lite-preview-09-2025
# qwen/qwen3-vl-235b-a22b-thinking
# qwen/qwen3-vl-235b-a22b-instruct
# qwen/qwen3-max
# qwen/qwen3-coder-plus
# openai/gpt-5-codex
# deepseek/deepseek-v3.1-terminus
# x-ai/grok-4-fast
# alibaba/tongyi-deepresearch-30b-a3b
# qwen/qwen3-coder-flash
# qwen/qwen3-next-80b-a3b-thinking
# qwen/qwen3-next-80b-a3b-instruct:free
# qwen/qwen3-next-80b-a3b-instruct
# qwen/qwen-plus-2025-07-28:thinking
# qwen/qwen-plus-2025-07-28
# nvidia/nemotron-nano-9b-v2:free
# nvidia/nemotron-nano-9b-v2
# moonshotai/kimi-k2-0905
# qwen/qwen3-30b-a3b-thinking-2507
# x-ai/grok-code-fast-1
# nousresearch/hermes-4-70b
# nousresearch/hermes-4-405b
# deepseek/deepseek-chat-v3.1
# openai/gpt-4o-audio-preview
# mistralai/mistral-medium-3.1
# baidu/ernie-4.5-21b-a3b
# baidu/ernie-4.5-vl-28b-a3b
# z-ai/glm-4.5v
# ai21/jamba-large-1.7
# openai/gpt-5-chat
# openai/gpt-5
# openai/gpt-5-mini
# openai/gpt-5-nano
# openai/gpt-oss-120b:free
# openai/gpt-oss-120b
# openai/gpt-oss-20b:free
# openai/gpt-oss-20b
# anthropic/claude-opus-4.1
# mistralai/codestral-2508
# qwen/qwen3-coder-30b-a3b-instruct
# qwen/qwen3-30b-a3b-instruct-2507
# z-ai/glm-4.5
# z-ai/glm-4.5-air:free
# z-ai/glm-4.5-air
# qwen/qwen3-235b-a22b-thinking-2507
# z-ai/glm-4-32b
# qwen/qwen3-coder:free
# qwen/qwen3-coder
# bytedance/ui-tars-1.5-7b
# google/gemini-2.5-flash-lite
# qwen/qwen3-235b-a22b-2507
# switchpoint/router
# moonshotai/kimi-k2
# mistralai/devstral-medium
# mistralai/devstral-small
# cognitivecomputations/dolphin-mistral-24b-venice-edition:free
# x-ai/grok-4
# tencent/hunyuan-a13b-instruct
# morph/morph-v3-large
# morph/morph-v3-fast
# baidu/ernie-4.5-vl-424b-a47b
# baidu/ernie-4.5-300b-a47b
# mistralai/mistral-small-3.2-24b-instruct
# minimax/minimax-m1
# google/gemini-2.5-flash
# google/gemini-2.5-pro
# openai/o3-pro
# x-ai/grok-3-mini
# x-ai/grok-3
# google/gemini-2.5-pro-preview
# deepseek/deepseek-r1-0528
# anthropic/claude-opus-4
# anthropic/claude-sonnet-4
# google/gemma-3n-e4b-it
# mistralai/mistral-medium-3
# google/gemini-2.5-pro-preview-05-06
# arcee-ai/spotlight
# arcee-ai/maestro-reasoning
# arcee-ai/virtuoso-large
# arcee-ai/coder-large
# meta-llama/llama-guard-4-12b
# qwen/qwen3-30b-a3b
# qwen/qwen3-8b
# qwen/qwen3-14b
# qwen/qwen3-32b
# qwen/qwen3-235b-a22b
# openai/o4-mini-high
# openai/o3
# openai/o4-mini
# openai/gpt-4.1
# openai/gpt-4.1-mini
# openai/gpt-4.1-nano
# alfredpros/codellama-7b-instruct-solidity
# x-ai/grok-3-mini-beta
# x-ai/grok-3-beta
# meta-llama/llama-4-maverick
# meta-llama/llama-4-scout
# deepseek/deepseek-chat-v3-0324
# openai/o1-pro
# mistralai/mistral-small-3.1-24b-instruct
# google/gemma-3-4b-it
# google/gemma-3-12b-it
# cohere/command-a
# openai/gpt-4o-mini-search-preview
# openai/gpt-4o-search-preview
# rekaai/reka-flash-3
# google/gemma-3-27b-it
# thedrummer/skyfall-36b-v2
# perplexity/sonar-reasoning-pro
# perplexity/sonar-pro
# perplexity/sonar-deep-research
# google/gemini-2.0-flash-lite-001
# mistralai/mistral-saba
# meta-llama/llama-guard-3-8b
# openai/o3-mini-high
# google/gemini-2.0-flash-001
# aion-labs/aion-1.0
# aion-labs/aion-1.0-mini
# aion-labs/aion-rp-llama-3.1-8b
# qwen/qwen2.5-vl-72b-instruct
# qwen/qwen-plus
# openai/o3-mini
# mistralai/mistral-small-24b-instruct-2501
# deepseek/deepseek-r1-distill-qwen-32b
# perplexity/sonar
# deepseek/deepseek-r1-distill-llama-70b
# deepseek/deepseek-r1
# minimax/minimax-01
# microsoft/phi-4
# sao10k/l3.1-70b-hanami-x1
# deepseek/deepseek-chat
# sao10k/l3.3-euryale-70b
# openai/o1
# cohere/command-r7b-12-2024
# meta-llama/llama-3.3-70b-instruct:free
# meta-llama/llama-3.3-70b-instruct
# amazon/nova-lite-v1
# amazon/nova-micro-v1
# amazon/nova-pro-v1
# openai/gpt-4o-2024-11-20
# mistralai/mistral-large-2411
# mistralai/mistral-large-2407
# mistralai/pixtral-large-2411
# qwen/qwen-2.5-coder-32b-instruct
# thedrummer/unslopnemo-12b
# anthropic/claude-3.5-haiku
# anthracite-org/magnum-v4-72b
# qwen/qwen-2.5-7b-instruct
# inflection/inflection-3-pi
# inflection/inflection-3-productivity
# thedrummer/rocinante-12b
# meta-llama/llama-3.2-3b-instruct:free
# meta-llama/llama-3.2-3b-instruct
# meta-llama/llama-3.2-11b-vision-instruct
# meta-llama/llama-3.2-1b-instruct
# qwen/qwen-2.5-72b-instruct
# cohere/command-r-08-2024
# cohere/command-r-plus-08-2024
# sao10k/l3.1-euryale-70b
# nousresearch/hermes-3-llama-3.1-70b
# nousresearch/hermes-3-llama-3.1-405b:free
# nousresearch/hermes-3-llama-3.1-405b
# sao10k/l3-lunaris-8b
# openai/gpt-4o-2024-08-06
# meta-llama/llama-3.1-70b-instruct
# meta-llama/llama-3.1-8b-instruct
# mistralai/mistral-nemo
# openai/gpt-4o-mini
# openai/gpt-4o-mini-2024-07-18
# google/gemma-2-27b-it
# sao10k/l3-euryale-70b
# nousresearch/hermes-2-pro-llama-3-8b
# openai/gpt-4o
# openai/gpt-4o-2024-05-13
# meta-llama/llama-3-8b-instruct
# meta-llama/llama-3-70b-instruct
# mistralai/mixtral-8x22b-instruct
# microsoft/wizardlm-2-8x22b
# openai/gpt-4-turbo
# anthropic/claude-3-haiku
# mistralai/mistral-large
# openai/gpt-3.5-turbo-0613
# openai/gpt-4-turbo-preview
# openrouter/auto
# openai/gpt-4-1106-preview
# openai/gpt-3.5-turbo-instruct
# mistralai/mistral-7b-instruct-v0.1
# openai/gpt-3.5-turbo-16k
# mancer/weaver
# undi95/remm-slerp-l2-13b
# gryphe/mythomax-l2-13b
# openai/gpt-4-0314
# openai/gpt-4
# openai/gpt-3.5-turbo

# %%
from openai import OpenAI
import os
# Create client
client = OpenAI(
    api_key=os.getenv("OPEN_ROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1"
)

# Chat completion
response = client.chat.completions.create(
    model="x-ai/grok-3",
    messages=[
        {
            "role": "system",
            "content": "You are a helpful AI assistant."
        },
        {
            "role": "user",
            "content": "Explain RAG in simple words"
        }
    ],
    temperature=0.7,
    max_tokens=500
)

# Print output
print(response.choices[0].message.content)
# Out:
# RAG, or Retrieval-Augmented Generation, is a technique used in artificial intelligence to make language models (like chatbots) smarter and more accurate by combining two steps: **retrieval** and **generation**.
#
# Here’s how it works in simple terms:
# 1. **Retrieval**: When you ask a question, the system first searches for relevant information or documents from a large database or knowledge base. Think of it like looking up facts in a library or on the internet.
# 2. **Generation**: After finding the most relevant information, the AI uses it to create a detailed and accurate response in natural language, instead of just relying on what it already "knows."
#
# ### Why is RAG useful?
# - It helps the AI give more up-to-date and specific answers by pulling in external information.
# - It reduces the chance of the AI making things up (hallucinations) because it bases its response on real data.
# - It’s like having a super-smart assistant who checks facts before answering.
#
# For example, if you ask, “What’s the latest news about space exploration?” a RAG system would first fetch the most recent articles or data about space, then summarize or explain them to you in a clear way.

# %%
# !pip install togethe/r
# Out:
# ERROR: Invalid requirement: 'togethe/r': Expected end or semicolon (after name and no valid version specifier)
#     togethe/r
#            ^

# %%
from together import Together

client = Together(api_key=os.getenv("TOGETHER_API_KEY"))

response = client.chat.completions.create(
    model="MiniMaxAI/MiniMax-M2.7",
    messages=[
        {
            "role": "system",
            "content": "You are a helpful AI assistant."
        },
        {
            "role": "user",
            "content": "Explain RAG in simple words"
        }
    ],
    temperature=0.7,
    max_tokens=512
)

print(response.choices[0].message.content)
# Out:
# # RAG Explained Simply
#
# **RAG = Retrieval-Augmented Generation**
#
# Think of it like a student taking an exam:
#
# ## The Problem with Regular AI
#
# Imagine a student (an AI model) who **memorized everything** from books up to 2023. If you ask about something new or very specific, they might guess or give outdated info.
#
# ## How RAG Works
#
# RAG adds a **research helper** to the student:
#
# 1. **You ask a question** → "What did Company X announce last week?"
#
# 2. **Retrieval** → The system quickly searches a database/documents to find relevant info
#
# 3. **Augmentation** → That found info is given to the AI along with your question
#
# 4. **Generation** → The AI now answers using both its knowledge AND the freshly retrieved information
#
# ## Simple Analogy
#
# | Without RAG | With RAG |
# |------------|----------|
# | Student answers from memory (may be wrong or outdated) | Student can open a textbook during the exam |
# | "I think it's..." | "Let me check... Ah yes, here's the answer!" |
#
# ## Why It Matters
#
# - ✅ **More accurate** answers
# - ✅ **Up-to-date** information
# - ✅ **Can cite sources**
# - ✅ Reduces "hallucinations" (made-up facts)
#
# **In short:** RAG lets AI "look things up" before answering, like you checking notes before a conversation.

# %%
from together import Together
import os

client = Together(
    api_key=os.environ["TOGETHER_API_KEY"]
)

models = client.models.list()

for model in models:
    print(model.id)
# Out:
# deepseek-ai/DeepSeek-V4-Pro
# zai-org/GLM-5.1
# moonshotai/Kimi-K2.6
# MiniMaxAI/MiniMax-M2.7
# google/gemma-4-31B-it
# Qwen/Qwen3.5-397B-A17B
# openai/gpt-oss-120b
# openai/gpt-oss-20b
# zai-org/GLM-5
# moonshotai/Kimi-K2.5
# deepseek-ai/DeepSeek-R1
# deepseek-ai/DeepSeek-V3.1
# Qwen/Qwen3.5-9B
# Qwen/Qwen3-Coder-Next-FP8
# Qwen/Qwen3-Coder-480B-A35B-Instruct-FP8
# Qwen/Qwen3-235B-A22B-Instruct-2507-tput
# Qwen/Qwen2.5-7B-Instruct-Turbo
# meta-llama/Llama-3.3-70B-Instruct-Turbo
# meta-llama/Meta-Llama-3-8B-Instruct-Lite
# google/gemma-3n-E4B-it
# hexgrad/Kokoro-82M
# canopylabs/orpheus-3b-0.1-ft
# openai/whisper-large-v3
# black-forest-labs/FLUX.1-schnell
# black-forest-labs/FLUX.1-krea-dev
# black-forest-labs/FLUX.1-kontext-pro
# black-forest-labs/FLUX.1-kontext-max
# black-forest-labs/FLUX.2-dev
# black-forest-labs/FLUX.2-flex
# black-forest-labs/FLUX.2-pro
# black-forest-labs/FLUX.2-max
# black-forest-labs/FLUX.1.1-pro
# meta-llama/Llama-Guard-4-12B
# intfloat/multilingual-e5-large-instruct
# arize-ai/qwen-2-1.5b-instruct
# LiquidAI/LFM2-24B-A2B
# essentialai/rnj-1-instruct
# nvidia/parakeet-tdt-0.6b-v3
# kwaivgI/kling-1.6-pro
# openai/gpt-image-1.5
# Wan-AI/Wan2.6-image
# google/veo-3.0-fast-audio
# vidu/vidu-q1
# cartesia/sonic
# ByteDance-Seed/Seedream-3.0
# ByteDance-Seed/Seedream-4.0
# Rundiffusion/Juggernaut-Lightning-Flux
# google/veo-3.0-audio
# kwaivgI/kling-2.1-master
# ideogram/ideogram-3.0
# kwaivgI/kling-2.1-pro
# Wan-AI/Wan2.2-I2V-A14B
# google/veo-2.0
# kwaivgI/kling-2.0-master
# openai/sora-2
# kwaivgI/kling-2.1-standard
# google/veo-3.0-fast
# google/gemini-3-pro-image
# vidu/vidu-2.0
# openai/sora-2-pro
# pixverse/pixverse-v5
# stabilityai/stable-diffusion-xl-base-1.0
# ByteDance/Seedance-1.0-lite
# cartesia/sonic-3
# ByteDance/Seedance-1.0-pro
# Wan-AI/Wan2.2-T2V-A14B
# HiDream-ai/HiDream-I1-Fast
# google/imagen-4.0-fast
# google/flash-image-2.5
# stabilityai/stable-diffusion-3-medium
# minimax/hailuo-02
# google/imagen-4.0-ultra
# google/imagen-4.0-preview
# RunDiffusion/Juggernaut-pro-flux
# Qwen/Qwen-Image
# HiDream-ai/HiDream-I1-Dev
# Lykon/DreamShaper
# google/veo-3.0
# HiDream-ai/HiDream-I1-Full
# kwaivgI/kling-1.6-standard
# minimax/video-01-director
# cartesia/sonic-2
# pixverse/pixverse-v5.6
# Qwen/Qwen-Image-2.0-Pro
# google/flash-image-3.1
# Qwen/Qwen-Image-2.0
# Wan-AI/wan2.7-t2v
# Wan-AI/wan2.7-i2v
# Wan-AI/wan2.7-r2v
# vidu/vidu-q3
# vidu/vidu-q3-turbo
# google/veo-3.1-test-debug
# deepcogito/cogito-v2-1-671b
# ByteDance/Seedance-2.0
# Qwen/Qwen3.6-Plus
# mistralai/Voxtral-Mini-3B-2507
# ByteDance/Seedream-5.0-lite
# pixverse/pixverse-v6
# xai/grok-imagine-image-pro
# alibaba/happyhorse-1.0-t2v
# alibaba/happyhorse-1.0-i2v
# alibaba/happyhorse-1.0-r2v
# meta-llama/Llama-3.3-70B-Instruct-Turbo-test
# mistralai/Mistral-Small-24B-Instruct-2501
# Qwen/Qwen3-VL-8B-Instruct
# google/gemma-4-E4B-it
# deepgram/aura-2
# Hcompany/Holo3-35B-A3B
# facebook/cwm
# google/gemma-4-26B-A4B-it
# Qwen/Qwen3-4B-Base
# Qwen/Qwen2-1.5B
# Qwen/Qwen3-Coder-30B-A3B-Instruct
# meta-llama/Meta-Llama-3.1-70B-Instruct-Turbo
# zai-org/GLM-4.7
# Qwen/Qwen3-VL-32B-Instruct
# NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO
# Qwen/Qwen2.5-32B
# Qwen/Qwen3-Next-80B-A3B-Thinking
# google/gemma-2-9b-it
# deepgram/flux
# deepgram/nova-3-en
# nim/meta/llama-3.1-70b-instruct
# nim/meta/llama-3.1-8b-instruct
# nim/nv-mistralai/mistral-nemo-12b-instruct
# nim/nvidia/llama-3.1-nemotron-70b-instruct
# deepcogito/cogito-v1-preview-llama-70B
# deepcogito/cogito-v1-preview-llama-70B-Turbo
# rime-labs/rime-arcana-v3-turbo
# nvidia/nemotron-3-nano-omni-30b-a3b-reasoning-fp8
# deepcogito/cogito-v1-preview-llama-8B
# deepcogito/cogito-v1-preview-qwen-14B
# deepcogito/cogito-v1-preview-qwen-32B
# deepgram/nova-3-multi
# deepseek-ai/DeepSeek-OCR-2
# deepseek-ai/DeepSeek-R1-Distill-Llama-70B
# deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B
# deepseek-ai/DeepSeek-R1-Distill-Qwen-14B
# google/gemma-3-4b-it
# deepseek-ai/DeepSeek-R1-Distill-Qwen-7B
# deepseek-ai/deepseek-coder-33b-instruct
# meta-llama/Llama-3.2-1B
# mistralai/Mixtral-8x7B-Instruct-v0.1-FP8-Lora
# google/gemma-3-27b-it
# google/gemma-3-270m-it-lora
# nvidia/NVIDIA-Nemotron-3-Super-120B-A12B-FP8
# zai-org/GLM-4.5-Air-FP8
# Qwen/Qwen2-72B
# Qwen/Qwen3-Next-80B-A3B-Instruct
# agentica-org/DeepCoder-14B-Preview
# mixedbread-ai/mxbai-rerank-large-v2
# Qwen/QwQ-32B
# Qwen/Qwen2-1.5B-Instruct
# Qwen/Qwen2-7B
# Qwen/Qwen2.5-1.5B
# Qwen/Qwen2.5-1.5B-Instruct
# Qwen/Qwen2.5-14B
# Qwen/Qwen2.5-3B-Instruct
# Qwen/Qwen2.5-72B
# Qwen/Qwen2.5-7B
# Qwen/Qwen2.5-7B-Instruct
# Qwen/Qwen2.5-Coder-32B-Instruct
# Qwen/Qwen2.5-VL-72B-Instruct
# Qwen/Qwen3-0.6B
# Qwen/Qwen3-0.6B-Base
# Qwen/Qwen3-1.7B
# Qwen/Qwen3-1.7B-Base
# Qwen/Qwen3-14B-Base
# Qwen/Qwen3-30B-A3B-Base
# Qwen/Qwen3-8B
# Qwen/Qwen3-8B-Base
# Qwen/Qwen3-Next-80B-A3B-Instruct-FP8
# Qwen/Qwen3-VL-235B-A22B-Instruct-FP8
# google/gemma-3-27b-pt
# meta-llama/Llama-2-7b-chat-hf
# nim/meta/llama-3.2-90b-vision-instruct
# google/gemma-2b-it
# mistralai/Magistral-Small-2506
# mistralai/Mistral-7B-Instruct-v0.1
# mistralai/Mistral-7B-v0.1
# Qwen/Qwen3-30B-A3B-Instruct-2507-Lora
# Qwen/Qwen3-4B-Instruct-2507
# Qwen/Qwen3-8B-Lora
# meta-llama/Llama-3.1-405B
# meta-llama/Meta-Llama-3.1-70B
# meta-llama/Llama-4-Maverick-17B-128E-Instruct-FP8
# meta-llama/Llama-3.2-3B
# nim/mistralai/mixtral-8x22b-instruct-v01
# togethercomputer/meta-llama-3.1-8B-Instruct-AWQ-INT4
# zai-org/GLM-4.5V
# zai-org/GLM-4.6
# zai-org/GLM-OCR
# meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo
# MiniMaxAI/MiniMax-M2
# Qwen/Qwen2.5-14B-Instruct
# google/gemma-4-E2B-it
# Qwen/Qwen3.6-35B-A3B-FP8
# nvidia/NVIDIA-Nemotron-3-Super-120B-A12B-BF16
# Qwen/Qwen3.5-122B-A10B-FP8
# rime-labs/rime-mist-v3
# meta-llama/Llama-3.1-405B-Instruct
# meta-llama/Llama-3.2-1B-Instruct
# Qwen/Qwen3-30B-A3B
# google/gemma-3-1b-it
# google/gemma-3-270m-it
# meta-llama/Llama-4-Scout-17B-16E
# meta-llama/Meta-Llama-3-70B-Instruct-Turbo
# meta-llama/Meta-Llama-3-8B-Instruct
# minimax/speech-2.6-turbo
# mistralai/Devstral-Small-2505
# mistralai/Ministral-3-14B-Instruct-2512
# mistralai/Mistral-7B-Instruct-v0.3
# mistralai/Mixtral-8x22B-Instruct-v0.1
# mistralai/Mixtral-8x7B-v0.1
# nim/meta/llama-3.2-11b-vision-instruct
# nim/meta/llama-3.3-70b-instruct
# nim/mistralai/mixtral-8x7b-instruct-v01
# nvidia/Llama-3.1-Nemotron-70B-Instruct-HF
# nvidia/NVIDIA-Nemotron-Nano-9B-v2
# rime-labs/rime-arcana-v2
# rime-labs/rime-arcana-v3
# rime-labs/rime-mist-v2
# sarvamai/sarvam-m
# togethercomputer/EssentialAI-RNJ-1-Instruct
# rime-labs/rime-mist-v3-omni
# mistralai/Mixtral-8x7B-Instruct-v0.1
# meta-llama/Meta-Llama-3.1-8B
# nvidia/NVIDIA-Nemotron-3-Nano-30B-A3B-BF16
# meta-llama/Llama-3.3-70B-Instruct
# meta-llama/Llama-3.3-70B-Instruct-FP8-Lora
# MiniMaxAI/MiniMax-M1-40k
# MiniMaxAI/MiniMax-M1-80k
# Qwen/Qwen2.5-72B-Instruct
# Qwen/Qwen2.5-72B-Instruct-Turbo
# Salesforce/Llama-Rank-V1
# nim/nvidia/llama-3.3-nemotron-super-49b-v1
# Qwen/Qwen2-VL-72B-Instruct
# google/gemma-2-27b-it
# Qwen/Qwen3.5-9B-FP8
# meta-llama/Llama-3-8b-chat-hf
# meta-llama/Llama-4-Scout-17B-16E-Instruct
# Qwen/Qwen3.5-35B-A3B

# %%
# /!pip install langchain langchain-opena/i

# %%
from langchain_openai import ChatOpenAI

from together import Together
import os

client = Together(
    api_key=os.environ["TOGETHER_API_KEY"]
)

models = client.models.list()

for model in models:
    try:
        print(f"****************************************{model.id}*************************************************")
        llm = ChatOpenAI(
            model=f"{model.id}",
            api_key=os.getenv("TOGETHER_API_KEY"),
            base_url="https://api.together.xyz/v1",
            temperature=0
        )

        context = """You are a helpful AI assistant."
        """

        question = "What is RAG?"

        prompt = f"""
        Answer What user asks.

        Context:
        {context}

        Question:
        {question}
        """

        response = llm.invoke(prompt)

        print(response.content)
    except Exception as e:
        print(f"Error with model {model.id}: {e}")
        continue
# Out:
# ****************************************deepseek-ai/DeepSeek-V4-Pro*************************************************
# RAG stands for **Retrieval-Augmented Generation**. It’s a technique in artificial intelligence that combines information retrieval with text generation to improve the accuracy and reliability of large language models (LLMs).
#
# ### How it works
# 1. **Retrieval**: When a user asks a question, the system first searches a knowledge base (e.g., a set of documents, a database, or the web) to find relevant information. This is often done using vector embeddings and similarity search.
# 2. **Augmentation**: The retrieved information is then added to the original prompt as context.
# 3. **Generation**: The LLM uses both the user’s query and the retrieved context to generate a final answer.
#
# ### Why RAG is useful
# - **Reduces hallucinations**: By grounding the response in real, retrieved data, the model is less likely to invent facts.
# - **Up-to-date knowledge**: The knowledge base can be updated independently of the model, so answers can reflect recent information without retraining.
# - **Domain-specific accuracy**: Organizations can use their own private documents, making the model an expert on proprietary or niche topics.
# - **Transparency**: The sources of the retrieved information can be cited, allowing users to verify the answer.
#
# ### Common use cases
# - Enterprise Q&A over internal documentation
# - Customer support chatbots
# - Research assistants that summarize scientific papers
# - Legal or medical applications where factual accuracy is critical
#
# In short, RAG makes LLMs more trustworthy and adaptable by letting them “look up” facts before they speak.
# ****************************************zai-org/GLM-5.1*************************************************
# **RAG** stands for **Retrieval-Augmented Generation**. It is a technique used in artificial intelligence that improves the accuracy and reliability of Large Language Models (LLMs) by giving them the ability to pull in information from external sources before generating a response.
#
# Here is a simple breakdown of how it works and why it is important:
#
# ### How RAG Works
# Imagine you are taking a test. Without RAG, an AI is like a student trying to answer questions purely from memory—sometimes they get it right, but other times they might misremember things or make stuff up (a phenomenon known as "hallucination").
#
# With RAG, the process changes to an "open-book" exam:
# 1. **Retrieval:** When you ask a question, the system first searches an external database (like your company's internal documents, a specific website, or an up-to-date news feed) to find information relevant to your query.
# 2. **Augmentation:** The system then combines (augments) your original question with the relevant information it just retrieved.
# 3. **Generation:** The LLM receives both your question and the retrieved context, and it generates an answer based specifically on that provided information.
#
# ### Why is RAG Important?
# * **Reduces Hallucinations:** Because the AI is basing its answer on retrieved facts rather than just its training data, it is much less likely to make up false information.
# * **Up-to-Date Information:** LLMs are trained on data up to a certain cutoff date. RAG allows the AI to access real-time or newly updated information (like today's stock prices or recent news).
# * **Access to Private Data:** RAG allows organizations to use AI to query their own proprietary, internal data without having to retrain or fine-tune the entire model on that data.
# * **Source Tracking:** Because the system retrieves specific documents to form its answer, it can usually cite its sources, allowing users to verify where the information came from.
#
# In short, RAG bridges the gap between the general knowledge an AI model was trained on and the specific, current, or private knowledge needed to answer a user's question accurately.
# ****************************************moonshotai/Kimi-K2.6*************************************************
# **RAG** stands for **Retrieval-Augmented Generation**.
#
# It is an AI technique that combines **information retrieval** (searching a database or knowledge base) with **text generation** (like what a large language model does) to produce more accurate, up-to-date, and contextually relevant responses.
#
# ### How it works:
# 1. **Retrieval**: When a user asks a question, the system first searches a trusted knowledge source (documents, databases, websites, etc.) to find relevant, factual information.
# 2. **Augmentation**: It feeds that retrieved information into the AI model as context.
# 3. **Generation**: The model then generates an answer based *both* on its training and the specific retrieved documents.
#
# ### Why it matters:
# - **Reduces hallucinations**: The model grounds its answers in retrieved facts rather than making things up.
# - **Stays current**: It can access information that wasn't in the model's original training data (e.g., recent events or private company documents).
# - **Customizable**: Organizations can use RAG to let AI answer questions based on their own internal documents without retraining the entire model.
#
# **Example**: If you ask a RAG-powered assistant about your company's vacation policy, it retrieves the latest HR handbook and answers based on that, rather than guessing from generic training data.
# ****************************************MiniMaxAI/MiniMax-M2.7*************************************************
# **RAG – Retrieval‑Augmented Generation**
#
# RAG is a popular technique in modern natural‑language‑processing (NLP) systems that **combines a retrieval (search) component with a generative language model**. The idea is to make the output of a large language model (LLM) more accurate, up‑to‑date, and grounded in real‑world information by first pulling relevant documents or facts from an external knowledge source and then using those retrieved pieces as context for the generator.
#
# ---
#
# ### How it works (high‑level)
#
# | Step | What happens | Typical technologies |
# |------|--------------|----------------------|
# | **1. Indexing** | A large corpus (e.g., Wikipedia, company docs, product manuals) is split into chunks and encoded into vector embeddings. | Sentence‑transformers, dense retrievers (e.g., DPR), BM25, FAISS, Annoy, ScaNN |
# | **2. Retrieval** | When a user query arrives, the system embeds the query and searches the index for the most similar chunks. | Vector similarity search, hybrid sparse‑dense retrieval |
# | **3. Augmentation** | The retrieved chunks (often top‑k) are concatenated with the original query to form an “augmented” prompt. | Prompt‑engineering, template‑based concatenation |
# | **4. Generation** | The LLM (e.g., GPT‑4, T5, BART, LLaMA) receives the augmented prompt and generates a response that can cite or incorporate the retrieved information. | Decoder‑only transformers, encoder‑decoder models |
#
# ---
#
# ### Why use RAG?
#
# | Benefit | Explanation |
# |---------|-------------|
# | **Reduced hallucination** | By grounding the generation in actual retrieved text, the model is less likely to “make up” facts. |
# | **Access to up‑to‑date knowledge** | The knowledge source can be refreshed independently of the model, allowing the system to stay current without retraining. |
# | **Domain‑specific grounding** | Companies can plug in internal documents, product FAQs, or legal texts so the model answers from that material. |
# | **Transparency & traceability** | Users can see which source documents were used, making it easier to verify answers. |
# | **Scalability** | Adding new documents only requires re‑indexing; the LLM itself stays the same. |
#
# ---
#
# ### Typical use‑cases
#
# - **Question‑Answering over large knowledge bases** (e.g., medical literature, technical support tickets).
# - **Chatbots that need factual, real‑time information** (stock prices, sports scores, weather).
# - **Enterprise search & summarization** (meeting minutes, policy manuals).
# - **Creative writing assistance** that pulls in factual references (e.g., “Write a blog post about the latest AI research, citing recent papers”).
#
# ---
#
# ### Common architectures
#
# | Architecture | Description |
# |--------------|-------------|
# | **Dense Passage Retriever (DPR) + Decoder‑only LLM** | DPR encodes query and passages into dense vectors; top‑k passages are fed to a GPT‑style model. |
# | **BM25 + Seq2Seq LLM** | Traditional sparse retrieval (BM25) combined with an encoder‑decoder model (e.g., T5). |
# | **Hybrid retrieval (BM25 + dense) + Fusion** | Combines scores from both retrieval methods for better recall. |
# | **Reranking + LLM** | A first retrieval stage returns a larger set; a cross‑encoder reranker narrows it down before generation. |
#
# ---
#
# ### Limitations & challenges
#
# | Issue | Why it matters |
# |-------|----------------|
# | **Retrieval quality** | If the retriever fetches irrelevant or noisy chunks, the final answer can be off‑target. |
# | **Latency** | Adding a retrieval step adds extra latency (especially with large indexes). |
# | **Context length** | LLMs have a finite context window; only a limited number of retrieved chunks can be included. |
# | **Chunk granularity** | Choosing the right chunk size (sentence, paragraph, page) affects both retrieval relevance and generation coherence. |
# | **Maintenance of the index** | The knowledge base must be kept up‑to‑date; stale indexes lead to outdated answers. |
#
# ---
#
# ### Quick example (pseudocode)
#
# ```python
# # 1. Encode query
# query_emb = embed_model.encode(user_query)
#
# # 2. Retrieve top‑k passages
# top_chunks = vector_index.search(query_emb, k=5)
#
# # 3. Build augmented prompt
# context = "\n".join([chunk.text for chunk in top_chunks])
# prompt = f"Context:\n{context}\n\nQuestion: {user_query}\nAnswer:"
#
# # 4. Generate answer
# answer = llm.generate(prompt)
# ```
#
# ---
#
# ### TL;DR
#
# - **RAG = Retrieval‑Augmented Generation**
# - **Combines a search/retrieval step with a generative language model** to produce answers that are more factual, current, and traceable.
# - **Key components**: a searchable knowledge index, a retriever, an augmentation step, and a generative model.
# - **Benefits**: reduces hallucinations, enables real‑time knowledge, and provides transparency.
# - **Common in**: Q&A bots, enterprise search, any knowledge‑intensive NLP application.
#
# ---
#
# > **Note:** “RAG” can also stand for other things (e.g., *Red‑Amber‑Green* risk ratings, *RAG* in finance, or *RAG* as a music genre), but in the context of AI and language models, **Retrieval‑Augmented Generation** is the most widely referenced meaning. If you had a different RAG in mind, feel free to clarify!
# ****************************************google/gemma-4-31B-it*************************************************
# **RAG** stands for **Retrieval-Augmented Generation**.
#
# In simple terms, it is a technique used to give a Large Language Model (LLM)—like GPT-4—access to data that was not part of its original training set.
#
# ### The Basic Concept: "Open-Book Exam"
# To understand RAG, think of the difference between two types of tests:
# *   **Standard LLM (Closed-Book):** The AI relies solely on its memory (what it learned during training). If the information is outdated or the AI doesn't know the specific answer, it might guess or "hallucinate."
# *   **RAG (Open-Book):** Before answering, the AI is allowed to look through a specific set of textbooks or documents to find the exact facts it needs, and then it summarizes those facts into a natural answer.
#
# ---
#
# ### How RAG Works (The Process)
# RAG happens in three main steps:
#
# 1.  **Retrieval:** When you ask a question, the system doesn't go straight to the LLM. Instead, it searches a separate database (usually a **Vector Database**) for documents or snippets of text that are mathematically similar to your question.
# 2.  **Augmentation:** The system takes the relevant snippets it found and "staples" them to your original question.
#     *   *Example Prompt to the AI:* "Using the following provided documents [Insert Document A and B], please answer the user's question: [Insert Question]."
# 3.  **Generation:** The LLM reads the provided context and generates an accurate response based on that specific information.
#
# ---
#
# ### Why is RAG useful?
# RAG solves several major problems inherent in standard AI models:
#
# *   **Up-to-Date Information:** You don't have to retrain a massive model every time a new fact emerges; you simply update the documents in your database.
# *   **Reduced Hallucinations:** Because the AI is told to answer based on provided text, it is much less likely to make things up.
# *   **Private Data:** Companies can use RAG to let an AI answer questions about their private internal manuals or emails without having to upload that sensitive data into the public training set of the AI provider.
# *   **Citations:** RAG allows the AI to tell you exactly which document it used to find the answer, making the response verifiable.
#
# ### Summary Table
# | Feature | Standard LLM | RAG-Enabled LLM |
# | :--- | :--- | :--- |
# | **Knowledge Source** | Training data (static) | Training data + External data (dynamic) |
# | **Accuracy** | Prone to hallucinations | Higher (grounded in facts) |
# | **Update Speed** | Requires expensive retraining | Instant (just add a new document) |
# | **Transparency** | "Black box" answer | Can provide citations/sources |
# ****************************************Qwen/Qwen3.5-397B-A17B*************************************************
# RAG stands for **Retrieval-Augmented Generation**. It is a technique used in artificial intelligence, particularly with Large Language Models (LLMs), to improve the accuracy and relevance of the answers they generate.
#
# Here is a simple breakdown of how it works:
#
# 1.  **Retrieval:** When you ask a question, the system searches an external knowledge base (such documents, databases, or the internet) to find relevant information.
# 2.  **Generation:** The system combines your original question with the retrieved information and sends it to the AI model. The model then generates a response based on that specific context.
#
# **Why is RAG important?**
# *   **Reduces Hallucinations:** By grounding answers in retrieved data, it helps prevent the AI from making up facts.
# *   **Access to Current Data:** It allows the AI to use up-to-date information beyond what it learned during its initial training.
# *   **Custom Knowledge:** It enables companies to use AI with their own private documents without needing to retrain the entire model.
#
# In short, RAG helps AI models answer questions more accurately by giving them access to the right reference materials before they respond.
# ****************************************openai/gpt-oss-120b*************************************************
# **RAG (Retrieval‑Augmented Generation)** is a technique that combines two powerful AI components:
#
# 1. **Retriever** – a system (often based on dense vector search or traditional keyword search) that quickly pulls relevant pieces of information (documents, passages, facts) from a large external knowledge base or corpus.
#
# 2. **Generator** – a language model (like GPT, T5, LLaMA, etc.) that takes the retrieved text as additional context and then produces a response, summary, answer, or any other generated output.
#
# ### How RAG works
# 1. **Query Input** – The user asks a question or provides a prompt.
# 2. **Retrieval Step** – The retriever searches a knowledge source (e.g., Wikipedia, internal documents, product manuals) and returns the top‑k most relevant chunks.
# 3. **Augmentation** – Those chunks are concatenated with the original query and fed into the generator.
# 4. **Generation Step** – The language model generates a response that is *grounded* in the retrieved information, often citing sources or staying factually accurate.
#
# ### Why use RAG?
# - **Improved factuality**: By grounding the generation in real documents, the model is less likely to hallucinate incorrect facts.
# - **Up‑to‑date knowledge**: The retriever can access a constantly refreshed corpus, so the system can answer questions about recent events without retraining the entire language model.
# - **Efficiency**: You can keep a relatively small (or even frozen) language model and still get high‑quality answers, because the heavy lifting of knowledge storage is handled by the external index.
# - **Domain specialization**: For specialized domains (medical, legal, technical), you can index domain‑specific documents and let the generator produce expert‑level answers without needing to train a massive model from scratch.
#
# ### Typical Architecture
# ```
# User Query
#    │
#    ▼
# Retriever (e.g., BM25, DPR, ColBERT, FAISS index)
#    │
#    ▼
# Top‑k Retrieved Passages
#    │
#    ▼
# Generator (e.g., T5, GPT‑3, LLaMA) + Prompt Engineering
#    │
#    ▼
# Final Answer / Output
# ```
#
# ### Variants & Extensions
# - **Hybrid Retrieval**: Combining sparse (BM25) and dense (embedding‑based) retrieval for better coverage.
# - **RAG‑Fusion**: Merging multiple retrieved passages into a single context before generation.
# - **RAG‑Token**: Feeding retrieved passages token‑by‑token into the generator, allowing the model to attend to each passage individually.
# - **Self‑RAG**: The model generates its own “pseudo‑documents” to retrieve from, useful when external corpora are limited.
#
# ### Real‑World Applications
# - **Customer support bots** that pull from product manuals and FAQs.
# - **Research assistants** that retrieve scientific papers and summarize findings.
# - **Code assistants** that fetch relevant API docs or Stack Overflow snippets before generating code suggestions.
# - **Enterprise knowledge bases** where employees ask questions and get answers grounded in internal documents.
#
# ### Quick Example
# **User query:** “What are the main differences between TCP and UDP?”
#
# **Retrieval step:** The system fetches two short passages from a networking textbook:
# 1. “TCP is connection‑oriented, provides reliable delivery, and includes flow control.”
# 2. “UDP is connection‑less, offers low latency, and does not guarantee delivery.”
#
# **Generation step:** The language model combines these facts and produces:
# > “TCP (Transmission Control Protocol) establishes a connection before data transfer, ensures reliable, ordered delivery, and includes mechanisms like flow control and congestion control. UDP (User Datagram Protocol) does not establish a connection, sends packets without guaranteeing delivery or order, and is typically used when low latency is more important than reliability, such as in streaming or online gaming.”
#
# ---
#
# **In short:** RAG = **Retrieval‑Augmented Generation**, a framework that enriches language‑model outputs with up‑to‑date, factual information retrieved from an external knowledge source, leading to more accurate, reliable, and domain‑specific results.
# ****************************************openai/gpt-oss-20b*************************************************
# **RAG** most commonly refers to **Retrieval‑Augmented Generation** – a modern approach in natural‑language processing that blends two key capabilities:
#
# | Step | What it does | Why it matters |
# |------|--------------|----------------|
# | **Retrieval** | The model searches a large knowledge base (e.g., a corpus of documents, a database, or the web) for passages that are relevant to the user’s query. | Provides up‑to‑date, domain‑specific facts that the language model alone might not know or might hallucinate. |
# | **Generation** | The language model (often a transformer like GPT‑4, Llama, etc.) takes the retrieved snippets as context and produces a fluent, coherent answer. | Allows the model to generate natural language while grounding its output in real evidence. |
#
# ### How it works in practice
#
# 1. **Query** – User asks a question.
# 2. **Retrieval** – A vector‑search engine (e.g., FAISS, ElasticSearch, or a custom index) returns the top‑k most relevant documents or passages.
# 3. **Prompt construction** – The retrieved text is inserted into a prompt that the generative model processes.
# 4. **Generation** – The model outputs an answer that references the retrieved content.
# 5. **Post‑processing** – Optionally, the answer is checked for factual consistency or filtered for style.
#
# ### Why RAG is useful
#
# - **Accuracy**: Reduces hallucinations by anchoring responses in real documents.
# - **Up‑to‑date**: Can pull in new information without retraining the entire model.
# - **Explainability**: The retrieved passages can be shown to users as evidence.
# - **Domain adaptation**: By indexing a specialized corpus, the same base model can answer highly technical questions.
#
# ### Typical use cases
#
# - Customer support bots that need to reference product manuals.
# - Academic assistants that pull from research papers.
# - Enterprise knowledge bases that keep policy documents current.
# - Medical triage systems that consult the latest guidelines.
#
# ---
#
# ### Other meanings of “RAG”
#
# | Context | Meaning |
# |---------|---------|
# | **Project management** | **Red‑Amber‑Green** status indicators for tasks or risks. |
# | **Education** | **RAG** (Red‑Amber‑Green) grading or assessment scales. |
# | **Finance** | **RAG** can be an abbreviation for “Risk‑Adjusted Growth” or similar metrics. |
# | **Sports** | **RAG** sometimes refers to “Rugby Association Group” or a club name. |
#
# If you had a different context in mind, let me know and I can tailor the explanation accordingly!
# ****************************************zai-org/GLM-5*************************************************
# **RAG** stands for **Retrieval-Augmented Generation**.
#
# It is a technique used in Artificial Intelligence to enhance the accuracy and reliability of Large Language Models (LLMs) by giving them the ability to access and utilize external, up-to-date information.
#
# Here is a simple breakdown of how it works and why it matters:
#
# ### The Problem RAG Solves
# Standard LLMs (like the base version of GPT-4 or Llama) rely solely on the data they were trained on. This leads to two main issues:
# 1.  **Outdated Information:** They do not know about events that happened after their training cutoff date.
# 2.  **Hallucinations:** They may confidently make up facts when they don't know the answer.
#
# ### How RAG Works
# Think of RAG as giving an AI an "open-book exam." Instead of answering purely from memory, the AI looks up the answer in a trusted source before responding.
#
# The process involves three main steps:
# 1.  **Retrieval:** When a user asks a question, the system searches an external knowledge base (like a company's internal documents, a database, or the live internet) to find relevant information.
# 2.  **Augmentation:** The system combines the user's question with the relevant information found in the retrieval step, creating a new, enriched prompt.
# 3.  **Generation:** The LLM processes this enriched prompt and generates an answer based strictly on the facts provided, ensuring higher accuracy.
#
# ### Key Benefits
# *   **Accuracy:** It reduces hallucinations because the model has specific facts to work with.
# *   **Up-to-date:** You can update the external knowledge base without having to retrain the entire AI model.
# *   **Private Data:** Companies can use RAG to let AI analyze their private, internal documents without leaking that data into public training sets.
# ****************************************moonshotai/Kimi-K2.5*************************************************
# RAG stands for **Retrieval-Augmented Generation**, an AI technique that combines information retrieval with text generation to produce more accurate, current, and verifiable responses.
#
# ## How it works:
#
# 1. **Retrieval**: When you ask a question, the system searches a knowledge base (documents, databases, or the internet) for relevant information
# 2. **Augmentation**: It retrieves the most pertinent facts/context and feeds them into the prompt
# 3. **Generation**: The language model uses this retrieved context to generate a response, rather than relying solely on its training data
#
# ## Key benefits:
#
# - **Reduced hallucinations**: The model grounds its answers in actual retrieved documents rather than "guessing"
# - **Current information**: Can access data beyond the model's training cutoff date
# - **Source attribution**: Can cite specific documents supporting its claims
# - **Domain expertise**: Can tap into specialized knowledge bases (medical, legal, technical) without retraining the entire model
#
# ## Common applications:
#
# - Enterprise chatbots that answer questions based on company documentation
# - Customer support systems pulling from knowledge bases
# - Research assistants analyzing academic papers
# - Systems like me (Kimi) when I search the web or reference uploaded documents
#
# In short, RAG bridges the gap between static language models and dynamic knowledge sources, making AI responses more factual and trustworthy.
# ****************************************deepseek-ai/DeepSeek-R1*************************************************
# RAG stands for **Retrieval-Augmented Generation**. It's a technique used in AI (especially large language models like me!) to improve the accuracy and relevance of responses by combining two key steps:
#
# 1.  **Retrieval:**
#     When you ask a question, the RAG system first searches a specific, predefined knowledge source (like a database, document repository, or knowledge base) to find the most relevant information related to your query. Think of it like a librarian quickly finding the best books on your topic.
#
# 2.  **Augmented Generation:**
#     The retrieved information is then fed *into* the language model (like me) along with your original question. The model uses *both* its general training knowledge *and* this specific retrieved context to generate a more accurate, informed, and up-to-date answer.
#
# **Why RAG is Important:**
#
# *   **Reduces Hallucinations:** Helps prevent the model from making up facts ("hallucinating") by grounding its response in retrieved evidence.
# *   **Improves Accuracy & Relevance:** Ensures answers are based on the most current and specific information available in the provided source.
# *   **Handles New Information:** Allows models to answer questions about data *not* included in their original training set (e.g., your company's internal documents, latest research papers).
# *   **Increases Transparency:** Makes it clearer *where* the information in the answer came from (the retrieved source).
#
# **Analogy:** Imagine you're writing a research paper. First, you look up relevant sources in a library (Retrieval). Then, you use your own writing skills *combined with* the information from those sources to write your paper (Augmented Generation).
#
# **In short:** RAG makes AI assistants like me smarter and more reliable by letting us "look up" specific information before answering your questions, leading to responses that are more factual, relevant, and trustworthy.
# ****************************************deepseek-ai/DeepSeek-V3.1*************************************************
# Of course!
#
# RAG stands for **Retrieval-Augmented Generation**.
#
# In simple terms, it's a powerful technique used in artificial intelligence (AI) to make large language models (LLMs) like me more accurate, reliable, and up-to-date.
#
# Here’s a breakdown of how it works and why it's important:
#
# ### How RAG Works (The Two-Step Process)
#
# 1.  **Retrieval:** When you ask a question, the RAG system first searches a specific, pre-defined database or set of documents (like your company's internal knowledge base, recent news articles, or technical manuals) to find information that is relevant to your query.
#
# 2.  **Augmented Generation:** The system then takes those relevant pieces of information and provides them as "context" to the language model. The LLM uses this fresh, specific context—along with its own vast training—to generate a highly accurate and contextualized answer for you.
#
# ### A Simple Analogy
#
# Think of it like an open-book exam:
# *   **Without RAG:** A student (the AI) has to answer a question from memory alone. They might be smart, but they could forget details, get facts slightly wrong, or not know about very recent events.
# *   **With RAG:** The same student is allowed to quickly look up the most relevant facts in a specific textbook (your database) *before* writing their answer. The answer is much more likely to be correct and precise.
#
# ### Why RAG is a Big Deal
#
# It solves several key limitations of standard LLMs:
#
# *   **Reduces "Hallucinations":** It grounds the AI's responses in factual, retrieved evidence, making its answers less likely to be made up or incorrect.
# *   **Access to Current Information:** Since it can retrieve from updated sources, it can answer questions about events that happened *after* the AI's original training data was cut off.
# *   **Access to Private Information:** It allows the AI to use internal, private data (e.g., company policies, project reports, proprietary research) that wasn't part of its public training data.
# *   **Source Transparency:** A good RAG system can often cite its sources (e.g., "According to document X..."), allowing you to verify the information for yourself.
#
# **In summary, RAG is a framework that combines the power of information retrieval with the generative power of language models to provide more factual, relevant, and trustworthy answers.** It's a core technology behind many modern, enterprise-grade AI chatbots and assistants.
# ****************************************Qwen/Qwen3.5-9B*************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 40
#      36
#      37         response = llm.invoke(prompt)
#      38
#      39         print(response.content)
# ---> 40     except Exception as e:
#      41         print(f"Error with model {model.id}: {e}")
#      42         continue
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\langchain_openai\chat_models\base.py:1650, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1643         return _construct_lc_result_from_responses_api(
#    1644             response,
#    1645             schema=original_schema_obj,
#    1646             metadata=generation_info,
#    1647             output_version=self.output_version,
#    1648         )
#    1649     else:
# -> 1650         raw_response = self.client.with_raw_response.create(**payload)
#    1651         response = raw_response.parse()
#    1652 except openai.BadRequestError as e:
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\openai\resources\chat\completions\completions.py:1215, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1168 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1169 def create(
#    1170     self,
#    (...)   1212     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1213 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1214     validate_response_format(response_format)
# -> 1215     return self._post(
#    1216         "/chat/completions",
#    1217         body=maybe_transform(
#    1218             {
#    1219                 "messages": messages,
#    1220                 "model": model,
#    1221                 "audio": audio,
#    1222                 "frequency_penalty": frequency_penalty,
#    1223                 "function_call": function_call,
#    1224                 "functions": functions,
#    1225                 "logit_bias": logit_bias,
#    1226                 "logprobs": logprobs,
#    1227                 "max_completion_tokens": max_completion_tokens,
#    1228                 "max_tokens": max_tokens,
#    1229                 "metadata": metadata,
#    1230                 "modalities": modalities,
#    1231                 "n": n,
#    1232                 "parallel_tool_calls": parallel_tool_calls,
#    1233                 "prediction": prediction,
#    1234                 "presence_penalty": presence_penalty,
#    1235                 "prompt_cache_key": prompt_cache_key,
#    1236                 "prompt_cache_retention": prompt_cache_retention,
#    1237                 "reasoning_effort": reasoning_effort,
#    1238                 "response_format": response_format,
#    1239                 "safety_identifier": safety_identifier,
#    1240                 "seed": seed,
#    1241                 "service_tier": service_tier,
#    1242                 "stop": stop,
#    1243                 "store": store,
#    1244                 "stream": stream,
#    1245                 "stream_options": stream_options,
#    1246                 "temperature": temperature,
#    1247                 "tool_choice": tool_choice,
#    1248                 "tools": tools,
#    1249                 "top_logprobs": top_logprobs,
#    1250                 "top_p": top_p,
#    1251                 "user": user,
#    1252                 "verbosity": verbosity,
#    1253                 "web_search_options": web_search_options,
#    1254             },
#    1255             completion_create_params.CompletionCreateParamsStreaming
#    1256             if stream
#    1257             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1258         ),
#    1259         options=make_request_options(
#    1260             extra_headers=extra_headers,
#    1261             extra_query=extra_query,
#    1262             extra_body=extra_body,
#    1263             timeout=timeout,
#    1264             security={"bearer_auth": True},
#    1265         ),
#    1266         cast_to=ChatCompletion,
#    1267         stream=stream or False,
#    1268         stream_cls=Stream[ChatCompletionChunk],
#    1269     )
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\openai\_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1035 response = None
#    1036 try:
# -> 1037     response = self._send_request(
#    1038         request,
#    1039         stream=stream or self._should_stream_response_body(request=request),
#    1040         **kwargs,
#    1041     )
#    1042 except httpx.TimeoutException as err:
#    1043     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\openai\_client.py:440, in OpenAI._send_request(self, request, stream, **kwargs)
#     432 @override
#     433 def _send_request(
#     434     self,
#    (...)    438     **kwargs: Unpack[HttpxSendArgs],
#     439 ) -> httpx.Response:
# --> 440     return self._send_with_auth_retry(request, stream=stream, **kwargs)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\openai\_client.py:418, in OpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     415         request.headers["Authorization"] = f"Bearer {self._workload_identity_auth.get_token()}"
#     416         used_workload_identity_auth = True
# --> 418 response = super()._send_request(request, stream=stream, **kwargs)
#     419 if (
#     420     response.status_code == 401
#     421     and self._workload_identity_auth is not None
#     422     and used_workload_identity_auth
#     423     and not retried
#     424 ):
#     425     response.close()
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\openai\_base_client.py:964, in SyncAPIClient._send_request(self, request, stream, **kwargs)
#     957 def _send_request(
#     958     self,
#     959     request: httpx.Request,
#    (...)    962     **kwargs: Unpack[HttpxSendArgs],
#     963 ) -> httpx.Response:
# --> 964     return self._client.send(request, stream=stream, **kwargs)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File d:\python scripts\Generative AI\Arise\arise\Lib\ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
